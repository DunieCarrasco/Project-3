# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
import os
from dotenv import load_dotenv

# Load .env enviroment variables into the notebook
load_dotenv()
# Get the API key from the environment variable and store as Python variable
usda_api_key = os.getenv("usda_api_key")
type(usda_api_key)
# Out:
# str

# %%
params_url='https://quickstats.nass.usda.gov/api/get_param_values/?key='+usda_api_key
group_desc = requests.get(params_url+'&param=group_desc').json()
commodity_desc=requests.get(params_url+'&param=commodity_desc').json()
region_desc=requests.get(params_url+'&param=region_desc').json()
location_desc=requests.get(params_url+'&param=location_desc').json()
state_alpha=requests.get(params_url+'&param=state_alpha').json()
state_name=requests.get(params_url+'&param=state_name').json()
domaincat_desc=requests.get(params_url+'&param=domaincat_desc').json()
domain_desc=requests.get(params_url+'&param=domain_desc').json()
year=requests.get(params_url+'&param=year').json()
sector_desc=requests.get(params_url+'&param=sector_desc').json()

api_params=[group_desc, commodity_desc,region_desc,domaincat_desc, year]
api_params
# Out:
# [{'group_desc': ['ANIMAL TOTALS',
#    'AQUACULTURE',
#    'COMMODITIES',
#    'CROP TOTALS',
#    'DAIRY',
#    'ENERGY',
#    'EXPENSES',
#    'FARMS & LAND & ASSETS',
#    'FIELD CROPS',
#    'FRUIT & TREE NUTS',
#    'HORTICULTURE',
#    'INCOME',
#    'IRRIGATION',
#    'LIVESTOCK',
#    'OPERATORS',
#    'POULTRY',
#    'PRICES PAID',
#    'PRODUCERS',
#    'SPECIALTY',
#    'VEGETABLES']},
#  {'commodity_desc': ['AG LAND',
#    'AG SERVICES',
#    'AG SERVICES & RENT',
#    'ALCOHOL COPRODUCTS',
#    'ALMONDS',
#    'ALPACAS',
#    'AMARANTH',
#    'ANIMAL PRODUCTS, OTHER',
#    'ANIMAL SECTOR',
#    'ANIMAL TOTALS',
#    'ANIMALS, OTHER',
#    'ANNUAL PPI',
#    'APPLES',
#    'APRICOTS',
#    'AQUACULTURE TOTALS',
#    'AQUACULTURE, OTHER',
#    'AQUATIC PLANTS',
#    'ARONIA BERRIES',
#    'ARTICHOKES',
#    'ASPARAGUS',
#    'ASSETS',
#    'AUTOMOBILES',
#    'AUTOS',
#    'AVOCADOS',
#    'BAITFISH',
#    'BANANAS',
#    'BAREROOT HERBACEOUS PERENNIALS',
#    'BARLEY',
# ...

# %%
sector_desc
# Out:
# {'sector_desc': ['ANIMALS & PRODUCTS',
#   'CROPS',
#   'DEMOGRAPHICS',
#   'ECONOMICS',
#   'ENVIRONMENTAL']}

# %%
data_url='https://quickstats.nass.usda.gov/api/api_GET/?key='+usda_api_key 
commodity_list=['CORN','APPLES','PEACHES','BANANAS','APRICOTS','CHERRIES','GRAPES','NECTARINES','LEMONS']
state_list=['CA','IA','NE','TX','IL','KS','MN','IN','NC','WI']

def get_api_results(stateList):
    
    url=data_url+'&source_desc=SURVEY&'+ \
                 '&sector_desc=CROPS&'+ \
                 '&group_desc%3DFRUIT%20TREE%20NUTS'+ \
                 'statisticcat_desc%3DAREA%20OPERATED&'+\
                 'unit_desc=ACRES&'+ \
                 'freq_desc=ANNUAL&'+ \
                 'reference_period_desc=YEAR&'+ \
                 'year__GE=1997&'+ \
                 'agg_level_desc=STATE&'
    
    for state in stateList:
        url=url+'state_alpha='+state+'&'
           
    
    url=url+'format=JSON'
    results_json = requests.get(url).json()
    return results_json



results=get_api_results(state_list)
results_df=pd.DataFrame(results['data'])
results_df.head()
len(results_df),len(results_df[results_df['Value'].str.contains('D')]),len(results_df[results_df['short_desc'].str.contains('ACERS')])
# Out:
# (18721, 416, 0)

# %%
results_df.head()
# Out:
#    year                short_desc commodity_desc statisticcat_desc  Value  \
# 0  2022  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  19000
# 1  2021  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  13000
# 2  2020  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  33000
# 3  2019  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  47000
# 4  2018  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  26000
#
#   state_alpha   group_desc   class_desc
# 0          CA  FIELD CROPS  ALL CLASSES
# 1          CA  FIELD CROPS  ALL CLASSES
# 2          CA  FIELD CROPS  ALL CLASSES
# 3          CA  FIELD CROPS  ALL CLASSES
# 4          CA  FIELD CROPS  ALL CLASSES

# %%
results_col=results_df.columns
results_col
# Out:
# Index(['state_fips_code', 'domain_desc', 'state_alpha', 'end_code',
#        'group_desc', 'county_ansi', 'week_ending', 'freq_desc',
#        'watershed_code', 'class_desc', 'commodity_desc', 'domaincat_desc',
#        'asd_code', 'watershed_desc', 'source_desc', 'CV (%)',
#        'statisticcat_desc', 'state_ansi', 'region_desc', 'unit_desc',
#        'country_code', 'util_practice_desc', 'zip_5', 'load_time',
#        'state_name', 'location_desc', 'country_name', 'county_name',
#        'asd_desc', 'reference_period_desc', 'Value', 'year', 'county_code',
#        'begin_code', 'prodn_practice_desc', 'congr_district_code',
#        'sector_desc', 'short_desc', 'agg_level_desc'],
#       dtype='object')

# %%
results_df['class_desc'].unique()
# Out:
# array(['ALL CLASSES', 'DRY EDIBLE, (EXCL CHICKPEAS)', 'DRY EDIBLE, BLACK',
#        'DRY EDIBLE, BLACKEYE', 'DRY EDIBLE, CRANBERRY',
#        'DRY EDIBLE, DARK, RED, KIDNEY', 'DRY EDIBLE, GREAT NORTHERN',
#        'DRY EDIBLE, INCL CHICKPEAS', 'DRY EDIBLE, LIGHT, RED, KIDNEY',
#        'DRY EDIBLE, LIMA', 'DRY EDIBLE, LIMA, BABY',
#        'DRY EDIBLE, LIMA, LARGE', 'DRY EDIBLE, NAVY', 'DRY EDIBLE, OTHER',
#        'DRY EDIBLE, OTHER, NOT LISTED', 'DRY EDIBLE, PINK',
#        'DRY EDIBLE, PINTO', 'DRY EDIBLE, RED, KIDNEY',
#        'DRY EDIBLE, SMALL, RED', 'DRY EDIBLE, SMALL, WHITE', 'LARGE',
#        'SMALL', 'PIMA', 'UPLAND', 'PRINCIPAL, INCL POTATOES',
#        '(EXCL ALFALFA)', 'ALFALFA', 'INDUSTRIAL', 'PROSO', 'PEPPERMINT',
#        'SPEARMINT', 'DRY EDIBLE', 'LONG GRAIN', 'MEDIUM GRAIN',
#        'SHORT GRAIN', 'NON-OIL TYPE', 'OIL TYPE',
#        'AIR-CURED LIGHT BURLEY (TYPE 31)',
#        'CIGAR BINDER NORTHERN WISCONSIN (TYPE 55)',
# ...

# %%
for col in results_col:
    desc_num=results_df[col].unique()
    num=len(desc_num)
    print (f'Total number of unique fields in {col} :{num}')
# Out:
# Total number of unique fields in state_fips_code :10
# Total number of unique fields in domain_desc :2
# Total number of unique fields in state_alpha :10
# Total number of unique fields in end_code :1
# Total number of unique fields in group_desc :4
# Total number of unique fields in county_ansi :1
# Total number of unique fields in week_ending :1
# Total number of unique fields in freq_desc :1
# Total number of unique fields in watershed_code :1
# Total number of unique fields in class_desc :86
# Total number of unique fields in commodity_desc :84
# Total number of unique fields in domaincat_desc :2
# Total number of unique fields in asd_code :1
# Total number of unique fields in watershed_desc :1
# Total number of unique fields in source_desc :1
# Total number of unique fields in CV (%) :1
# Total number of unique fields in statisticcat_desc :5
# Total number of unique fields in state_ansi :10
# Total number of unique fields in region_desc :1
# ...

# %%
drop_columns=['domain_desc','end_code','state_fips_code',
              'county_ansi','domaincat_desc','watershed_code','freq_desc','week_ending',
              'state_ansi','watershed_desc','watershed_desc', 'source_desc',
       'CV (%)', 'asd_code', 'load_time', 'state_name', 'country_code',
       'zip_5', 'util_practice_desc', 'unit_desc', 'region_desc',
       'country_name', 'county_name', 'location_desc', 'begin_code',
       'county_code', 'reference_period_desc',  'asd_desc', 
       'agg_level_desc', 'prodn_practice_desc', 'congr_district_code',
       'sector_desc']

# %%
results_df.drop(columns=drop_columns,axis=1,inplace=True)

# %%
results_df.head()
# Out:
#    year                short_desc commodity_desc statisticcat_desc   Value  \
# 0  2022  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  19,000
# 1  2021  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  13,000
# 2  2020  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  33,000
# 3  2019  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  47,000
# 4  2018  BARLEY - ACRES HARVESTED         BARLEY    AREA HARVESTED  26,000
#
#   state_alpha   group_desc   class_desc
# 0          CA  FIELD CROPS  ALL CLASSES
# 1          CA  FIELD CROPS  ALL CLASSES
# 2          CA  FIELD CROPS  ALL CLASSES
# 3          CA  FIELD CROPS  ALL CLASSES
# 4          CA  FIELD CROPS  ALL CLASSES

# %%
results_df['short_desc'].unique()
# Out:
# array(['BARLEY - ACRES HARVESTED', 'BARLEY - ACRES PLANTED',
#        'BARLEY, IRRIGATED - ACRES HARVESTED',
#        'BARLEY, IRRIGATED - ACRES PLANTED',
#        'BARLEY, NON-IRRIGATED - ACRES HARVESTED',
#        'BARLEY, NON-IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, BLACK - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, BLACK - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, BLACKEYE - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, BLACKEYE - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, CRANBERRY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, CRANBERRY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, DARK, RED, KIDNEY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, DARK, RED, KIDNEY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, GREAT NORTHERN - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, GREAT NORTHERN - ACRES PLANTED',
# ...

# %%
len(results_df)
# Out:
# 18255

# %%
results_df.columns
# Out:
# Index(['year', 'short_desc', 'commodity_desc', 'statisticcat_desc', 'Value',
#        'state_alpha', 'group_desc', 'class_desc'],
#       dtype='object')

# %%
results_df['state_alpha'].unique()
# Out:
# array(['CA', 'KS', 'MN', 'NE', 'NC', 'TX', 'WI', 'IL', 'IN', 'IA'],
#       dtype=object)

# %%
results_df['Value']=results_df['Value'].str.replace(',','')
results_df=results_df[results_df['Value'].str.isdigit()== True]
results_df['Value']=results_df['Value'].astype(int)
results_df['Value'].describe()
# Out:
# C:\Users\sara_\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# count    1.825500e+04
# mean     1.190070e+06
# std      3.366792e+06
# min      0.000000e+00
# 25%      9.000000e+03
# 50%      5.000000e+04
# 75%      4.880000e+05
# max      2.502000e+07
# Name: Value, dtype: float64

# %%
results_df.dtypes
# Out:
# year                  int64
# short_desc           object
# commodity_desc       object
# statisticcat_desc    object
# Value                 int32
# state_alpha          object
# group_desc           object
# class_desc           object
# dtype: object

# %%
results_df.groupby('state_alpha')['Value'].describe()
# Out:
#               count          mean           std    min      25%       50%  \
# state_alpha
# CA           4431.0  1.662507e+05  4.624432e+05    0.0   9000.0   31000.0
# IA            563.0  4.611349e+06  7.667978e+06   95.0  45000.0  330000.0
# IL            996.0  2.464594e+06  5.799435e+06    0.0   9225.0   44350.0
# IN            894.0  1.445231e+06  3.194133e+06   67.0   4900.0   15000.0
# KS           1609.0  2.708174e+06  4.600475e+06    0.0  37000.0  545000.0
# MN           1786.0  1.260180e+06  3.605768e+06    0.0  19450.0   66000.0
# NC           1574.0  3.521499e+05  8.705846e+05  160.0   5500.0   18800.0
# NE           1903.0  1.531209e+06  3.477503e+06    0.0  28000.0  120000.0
# TX           3019.0  1.160502e+06  2.979313e+06    0.0   6100.0   38000.0
# WI           1480.0  7.197615e+05  1.611385e+06    0.0   5600.0   66000.0
#
#                    75%         max
# state_alpha
# CA            114000.0   5193000.0
# IA           9565000.0  25020000.0
# ...

# %%
results_df.to_json('products.json')

# %%
len(results_df['commodity_desc'].unique())
# Out:
# 84

# %%
results_df['year'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001,
#        2000, 1999, 1998, 1997, 2023], dtype=int64)

# %%
commodity_sorted=results_df.groupby('commodity_desc').sum()['Value'].sort_values(ascending=False)

commodity_list=[]
for index, value in commodity_sorted.items():
    commodity_list.append(index)
        
commodity_list
# Out:
# ['FIELD CROP TOTALS',
#  'CORN',
#  'WHEAT',
#  'SOYBEANS',
#  'HAY',
#  'COTTON',
#  'HAY & HAYLAGE',
#  'SORGHUM',
#  'HAYLAGE',
#  'RICE',
#  'OATS',
#  'BEANS',
#  'VEGETABLE TOTALS',
#  'SUNFLOWER',
#  'SUGARBEETS',
#  'GRAPES',
#  'PEANUTS',
#  'POTATOES',
#  'TOMATOES',
#  'BARLEY',
#  'ALMONDS',
#  'SWEET CORN',
#  'TOBACCO',
#  'LETTUCE',
#  'ORANGES',
#  'PEAS',
#  'MILLET',
#  'BROCCOLI',
#  'MELONS',
#  'WALNUTS',
#  'CITRUS TOTALS',
#  'SWEET POTATOES',
#  'CARROTS',
#  'PISTACHIOS',
#  'CANOLA',
#  'RYE',
#  'ONIONS',
#  'SUGARCANE',
#  'SAFFLOWER',
#  'CAULIFLOWER',
#  'STRAWBERRIES',
#  'SPINACH',
#  'CUCUMBERS',
#  'PEPPERS',
#  'CABBAGE',
#  'PEACHES',
#  'GARLIC',
#  'CELERY',
#  'CHICKPEAS',
#  'LEMONS',
#  'PUMPKINS',
#  'ASPARAGUS',
#  'TANGERINES',
#  'PECANS',
#  'PRUNES',
#  'GRAPEFRUIT',
#  'AVOCADOS',
#  'OLIVES',
#  'SQUASH',
#  'CHERRIES',
#  'MINT',
#  'APPLES',
#  'ARTICHOKES',
#  'PEARS',
#  'CRANBERRIES',
#  'NECTARINES',
#  'PLUMS',
#  'FLAXSEED',
# ...

# %%
fruit_list=['GRAPES','ORANGES','STRAWBERRIES','PEACHES','TANGERINES','GRAPEFRUIT',
            'CHERRIES','APPLES','PEARS','CRANBERRIES','NECTARINES','PLUMS','BLUEBERRIES',
            'RASPBERRIES','APRICOTS','KIWIFRUIT']

fruit_df=results_df[results_df['commodity_desc'].isin(fruit_list)]

# %%
grain_list=[ 'WHEAT','OATS','BARLEY','FLAXSEED']
grain_df=results_df[results_df['commodity_desc'].isin(grain_list)]

# %%
vegetable_list=[ 'CORN', 'SOYBEANS', 'MELONS','BEANS','POTATOES', 'TOMATOES','CARROTS',
                 'ONIONS','CUCUMBERS','PEPPERS','GARLIC', 'CELERY','SQUASH','BEETS','EGGPLANT']

vegetable_df=results_df[results_df['commodity_desc'].isin(vegetable_list)]

# %%
len(fruit_df),len(grain_df),len(vegetable_df)
# Out:
# (802, 2712, 6782)

# %%
fruit_df.groupby('commodity_desc')['state_alpha'].nunique().sort_values(ascending=False).to_frame().plot(kind='bar')
plt.ylabel('Total Number of states')
plt.xlabel('Fruits')
# Out:
# Text(0.5, 0, 'Fruits')

# %%
fruit_list=['GRAPES','ORANGES','STRAWBERRIES','PEACHES','TANGERINES','GRAPEFRUIT',
            'CHERRIES','APPLES','PEARS','CRANBERRIES','NECTARINES','PLUMS','BLUEBERRIES',
            'RASPBERRIES','APRICOTS','KIWIFRUIT']

grain_list=[ 'WHEAT','OATS','BARLEY','FLAXSEED']

# %%
fruit_df[fruit_df['commodity_desc']=='APPLES'].groupby('state_alpha').sum()['Value'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='state_alpha'>

# %%
for year in range(1997,2023):
    fruits=fruit_df[fruit_df['year']==year]['commodity_desc'].unique()
    print(f'fruits in {year}: {fruits}')
# Out:
# fruits in 1997: ['GRAPEFRUIT' 'ORANGES' 'TANGERINES']
# fruits in 1998: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 1999: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2000: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2001: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2002: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2003: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2004: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2005: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2006: ['GRAPEFRUIT' 'ORANGES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# fruits in 2007: ['APPLES' 'APRICOTS' 'BLUEBERRIES' 'CHERRIES' 'CRANBERRIES' 'GRAPEFRUIT'
#  'GRAPES' 'KIWIFRUIT' 'NECTARINES' 'ORANGES' 'PEACHES' 'PEARS' 'PLUMS'
#  'RASPBERRIES' 'STRAWBERRIES' 'TANGERINES' 'MELONS']
# ...

# %%
for year in range(1997,2023):
    grains=grain_df[grain_df['year']==year]['commodity_desc'].unique()
    print(f'grains in {year}: {grains}')
# Out:
# grains in 1997: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 1998: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 1999: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2000: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2001: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2002: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2003: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2004: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2005: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2006: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2007: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2008: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2009: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2010: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2011: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2012: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2013: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# grains in 2014: ['BARLEY' 'FLAXSEED' 'OATS' 'WHEAT']
# ...

# %%
for year in range(1997,2023):
    vegetables=vegetable_df[vegetable_df['year']==year]['commodity_desc'].unique()
    print(f'vegetables in {year}: {vegetables}')
# Out:
# vegetables in 1997: ['BEANS' 'CORN' 'SOYBEANS' 'POTATOES' 'TOMATOES']
# vegetables in 1998: ['BEANS' 'CORN' 'SOYBEANS' 'BEETS' 'CARROTS' 'CELERY' 'CUCUMBERS' 'GARLIC'
#  'ONIONS' 'PEPPERS' 'POTATOES' 'TOMATOES']
# vegetables in 1999: ['BEANS' 'CORN' 'SOYBEANS' 'BEETS' 'CARROTS' 'CELERY' 'CUCUMBERS' 'GARLIC'
#  'ONIONS' 'PEPPERS' 'POTATOES' 'TOMATOES']
# vegetables in 2000: ['BEANS' 'CORN' 'SOYBEANS' 'BEETS' 'CARROTS' 'CELERY' 'CUCUMBERS'
#  'EGGPLANT' 'GARLIC' 'ONIONS' 'PEPPERS' 'POTATOES' 'SQUASH' 'TOMATOES']
# vegetables in 2001: ['BEANS' 'CORN' 'SOYBEANS' 'CARROTS' 'CELERY' 'CUCUMBERS' 'EGGPLANT'
#  'GARLIC' 'ONIONS' 'PEPPERS' 'POTATOES' 'SQUASH' 'TOMATOES']
# vegetables in 2002: ['BEANS' 'CORN' 'SOYBEANS' 'CARROTS' 'CELERY' 'CUCUMBERS' 'GARLIC'
#  'ONIONS' 'PEPPERS' 'POTATOES' 'SQUASH' 'TOMATOES']
# vegetables in 2003: ['BEANS' 'CORN' 'SOYBEANS' 'CARROTS' 'CELERY' 'CUCUMBERS' 'GARLIC'
#  'ONIONS' 'PEPPERS' 'POTATOES' 'SQUASH' 'TOMATOES']
# ...

# %%
fruit_df[(fruit_df['commodity_desc']=='APPLES') & (fruit_df['year']==2010)].groupby('state_alpha').sum()['Value'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='state_alpha'>

# %% [markdown]
# <h2>*********  PLOTS ************</h2>

# %%
def fruit_plot(fruit_name):
    fruit_name=fruit_name.upper()
    fruit_df[fruit_df['commodity_desc']==fruit_name].groupby('state_alpha').sum()['Value'].plot(kind='bar',align = "center", figsize=(15,10))
    plt.xlabel('States')
    plt.ylabel('Acers Harvested')
    plt.title(fruit_name)

def grain_plot(grain_name):
    grain_name=grain_name.upper()
    grain_df[grain_df['commodity_desc']==grain_name].groupby('state_alpha').sum()['Value'].plot(kind='bar',align = "center", figsize=(15,10))
    plt.xlabel('States')
    plt.ylabel('Acers Harvested')
    plt.title(grain_name)
    
def vegetable_plot(vegetable_name):
    vegetable_name=vegetable_name.upper()
    vegetable_df[vegetable_df['commodity_desc']==vegetable_name].groupby('state_alpha').sum()['Value'].plot(kind='bar',align = "center", figsize=(15,10))
    plt.xlabel('States')
    plt.ylabel('Acers Harvested')
    plt.title(vegetable_name)

# %%
def state_plot(state,commodity_type,year=[]):
    if year==[]:
        if commodity_type=='grain':
            grain_df[grain_df['state_alpha']==state.upper()]. \
            groupby('commodity_desc').sum()['Value']. \
            sort_values(ascending=False).plot(kind='bar')
        elif commodity_type=='vegetable':
            vegetable_df[vegetable_df['state_alpha']==state.upper()]. \
            groupby('commodity_desc').sum()['Value']. \
            sort_values(ascending=False).plot(kind='bar')
        else:
            fruit_df[fruit_df['state_alpha']==state.upper()]. \
            groupby('commodity_desc').sum()['Value']. \
            sort_values(ascending=False).plot(kind='bar')

    else:
        if commodity_type=='grain':
            grain_df[(grain_df['state_alpha']==state.upper()) & (grain_df['year'].isin(year))]. \
            groupby('commodity_desc').sum()['Value']. \
            sort_values(ascending=False).plot(kind='bar')
        elif commodity_type=='vegetable':
            vegetable_df[(vegetable_df['state_alpha']==state.upper()) & (vegetable_df['year'].isin(year))]. \
            groupby('commodity_desc').sum()['Value']. \
            sort_values(ascending=False).plot(kind='bar')
        else:
            fruit_df[(fruit_df['state_alpha']==state.upper()) & (fruit_df['year'].isin(year))]. \
            groupby('commodity_desc').sum()['Value']. \
            sort_values(ascending=False).plot(kind='bar')

# %%
state_plot('mn','vegetable',[2000])

# %%
vegetable_list
# Out:
# ['CORN',
#  'SOYBEANS',
#  'MELONS',
#  'BEANS',
#  'POTATOES',
#  'TOMATOES',
#  'CARROTS',
#  'ONIONS',
#  'CUCUMBERS',
#  'PEPPERS',
#  'GARLIC',
#  'CELERY',
#  'SQUASH',
#  'BEETS',
#  'EGGPLANT']

# %%
vegetable_plot('potatoes')

# %%
fruit_plot('apples')

# %%
# Out:
#              year                                         short_desc  \
# state_alpha
# CA           2023       WHEAT, WINTER, NON-IRRIGATED - ACRES PLANTED
# IA           2022                      WHEAT, WINTER - ACRES PLANTED
# IL           2023                      WHEAT, WINTER - ACRES PLANTED
# IN           2023                      WHEAT, WINTER - ACRES PLANTED
# KS           2023  WHEAT, WINTER, NON-IRRIGATED, FOLLOWING SUMMER...
# MN           2022                      WHEAT, WINTER - ACRES PLANTED
# NC           2023                      WHEAT, WINTER - ACRES PLANTED
# NE           2023       WHEAT, WINTER, NON-IRRIGATED - ACRES PLANTED
# TX           2023       WHEAT, WINTER, NON-IRRIGATED - ACRES PLANTED
# WI           2023                      WHEAT, WINTER - ACRES PLANTED
#
#             commodity_desc statisticcat_desc     Value   group_desc class_desc
# state_alpha
# CA                   WHEAT      AREA PLANTED    880000  FIELD CROPS     WINTER
# ...

# %%
import plotly.express as px
df = px.data.gapminder()

fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
         size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()
