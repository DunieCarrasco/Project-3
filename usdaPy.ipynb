# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
import os
from dotenv import load_dotenv

# Load .env enviroment variables into the notebook
load_dotenv()
# Get the API key from the environment variable and store as Python variable
usda_api_key = os.getenv("usda_api_key")
type(usda_api_key)
# Out:
# str

# %%
params_url='https://quickstats.nass.usda.gov/api/get_param_values/?key='+usda_api_key
group_desc = requests.get(params_url+'&param=group_desc').json()
commodity_desc=requests.get(params_url+'&param=commodity_desc').json()
region_desc=requests.get(params_url+'&param=region_desc').json()
location_desc=requests.get(params_url+'&param=location_desc').json()
state_alpha=requests.get(params_url+'&param=state_alpha').json()
state_name=requests.get(params_url+'&param=state_name').json()
domaincat_desc=requests.get(params_url+'&param=domaincat_desc').json()
domain_desc=requests.get(params_url+'&param=domain_desc').json()
year=requests.get(params_url+'&param=year').json()
sector_desc=requests.get(params_url+'&param=sector_desc').json()

api_params=[group_desc, commodity_desc,region_desc,domaincat_desc, year]
api_params
# Out:
# [{'group_desc': ['ANIMAL TOTALS',
#    'AQUACULTURE',
#    'COMMODITIES',
#    'CROP TOTALS',
#    'DAIRY',
#    'ENERGY',
#    'EXPENSES',
#    'FARMS & LAND & ASSETS',
#    'FIELD CROPS',
#    'FRUIT & TREE NUTS',
#    'HORTICULTURE',
#    'INCOME',
#    'IRRIGATION',
#    'LIVESTOCK',
#    'OPERATORS',
#    'POULTRY',
#    'PRICES PAID',
#    'PRODUCERS',
#    'SPECIALTY',
#    'VEGETABLES']},
#  {'commodity_desc': ['AG LAND',
#    'AG SERVICES',
#    'AG SERVICES & RENT',
#    'ALCOHOL COPRODUCTS',
#    'ALMONDS',
#    'ALPACAS',
#    'AMARANTH',
#    'ANIMAL PRODUCTS, OTHER',
#    'ANIMAL SECTOR',
#    'ANIMAL TOTALS',
#    'ANIMALS, OTHER',
#    'ANNUAL PPI',
#    'APPLES',
#    'APRICOTS',
#    'AQUACULTURE TOTALS',
#    'AQUACULTURE, OTHER',
#    'AQUATIC PLANTS',
#    'ARONIA BERRIES',
#    'ARTICHOKES',
#    'ASPARAGUS',
#    'ASSETS',
#    'AUTOMOBILES',
#    'AUTOS',
#    'AVOCADOS',
#    'BAITFISH',
#    'BANANAS',
#    'BAREROOT HERBACEOUS PERENNIALS',
#    'BARLEY',
#    'BASIL',
#    'BEANS',
#    'BEDDING PLANT TOTALS',
#    'BEDDING PLANTS, ANNUAL',
#    'BEDDING PLANTS, HERBACEOUS PERENNIAL',
#    'BEEF',
#    'BEESWAX',
#    'BEETS',
#    'BERRIES, OTHER',
#    'BERRY TOTALS',
#    'BETEL NUTS',
#    'BISON',
#    'BITTERMELON',
#    'BLACKBERRIES',
#    'BLUEBERRIES',
#    'BOATS',
#    'BOYSENBERRIES',
#    'BREADFRUIT',
#    'BROCCOLI',
#    'BRUSSELS SPROUTS',
#    'BUCKWHEAT',
#    'BUILDING MATERIALS',
#    'BUILDINGS',
#    'BULBS & CORMS & RHIZOMES & TUBERS',
#    'BULBS & ROOTS',
#    'BUSINESS ACTIVITY',
#    'BUTTER',
#    'BUTTERMILK',
#    'CABBAGE',
#    'CACAO',
#    'CACTI & SUCCULENTS',
#    'CAKE & MEAL',
#    'CAMELINA',
#    'CANEBERRIES',
#    'CANOLA',
#    'CARABAO',
#    'CARROTS',
#    'CASH RECEIPT TOTALS',
#    'CASSAVA',
#    'CATTLE',
#    'CAULIFLOWER',
#    'CCC LOANS',
#    'CELERY',
#    'CHAIN SAWS',
#    'CHEESE',
#    'CHEMICAL TOTALS',
#    'CHEMICALS, OTHER',
#    'CHERIMOYAS',
#    'CHERRIES',
#    'CHESTNUTS',
#    'CHICKENS',
#    'CHICKPEAS',
#    'CHICORY',
#    'CHIRONJAS',
#    'CHIVES',
#    'CHUKARS',
#    'CILANTRO',
#    'CITRONS',
#    'CITRUS TOTALS',
#    'CITRUS, OTHER',
#    'COCONUTS',
#    'COFFEE',
#    'COFFEE DEPULPERS',
#    'COFFEE DRYERS',
#    'COFFEE WASHERS',
#    'COLD STORAGE CAPACITY',
#    'COMMODITY TOTALS',
#    'COMPUTERS',
#    'CONSUMER PRICE INDEX',
#    'CORIANDER',
#    'CORN',
#    'COTTON',
#    'CRAMBE',
#    'CRANBERRIES',
#    'CREAM',
#    'CROP SECTOR',
#    'CROP TOTALS',
#    'CROPS, OTHER',
#    'CRUDE PINE GUM',
#    'CRUSTACEANS',
#    'CUCUMBERS',
#    'CURRANTS',
#    'CUT CHRISTMAS TREES',
#    'CUT CHRISTMAS TREES & SHORT TERM WOODY CROPS',
#    'CUT CULTIVATED GREENS',
#    'CUT FLOWERS',
#    'CUT FLOWERS & CUT CULTIVATED GREENS',
#    'DAIKON',
#    'DAIRY PRODUCT TOTALS',
#    'DAIRY PRODUCTS, OTHER',
#    'DASHEENS',
#    'DATES',
#    'DEBT',
#    'DECIDUOUS FLOWERING TREES',
#    'DECIDUOUS SHADE TREES',
#    'DECIDUOUS SHRUBS',
#    'DEER',
#    'DEPRECIATION',
#    'DILL',
#    'DRAGON FRUIT',
#    'DUCKS',
#    'EGGPLANT',
#    'EGGS',
#    'ELDERBERRIES',
#    'ELECTRICITY',
#    'ELK',
#    'EMERGENCY ELECTRIC GENERATORS',
#    'EMMER & SPELT',
#    'EMUS',
#    'ENERGY',
#    'EQUINE',
#    'EQUIPMENT, OTHER',
#    'ESCAROLE & ENDIVE',
#    'EVERGREENS, BROADLEAF',
#    'EVERGREENS, CONIFEROUS',
#    'EXPENSE TOTALS',
#    'EXPENSES, OTHER',
#    'FACILITIES & EQUIPMENT',
#    'FARM BY-PRODUCTS & WASTE',
#    'FARM OPERATIONS',
#    'FARM SECTOR',
#    'FEED',
#    'FEED GRAINS',
#    'FEED GRAINS & HAY',
#    'FEED PRICE RATIO',
#    'FERTILIZER',
#    'FERTILIZER & CHEMICAL TOTALS',
#    'FERTILIZER TOTALS',
#    'FERTILIZER, MIXED',
#    'FERTILIZER, OTHER',
#    'FIELD CROP & VEGETABLE TOTALS',
#    'FIELD CROP TOTALS',
#    'FIELD CROPS & VEGETABLES, OTHER',
#    'FIELD CROPS, OTHER',
#    'FIELDWORK',
#    'FIGS',
#    'FISH',
#    'FISH & GIANT CLAMS',
#    'FLAXSEED',
#    'FLORICULTURE TOTALS',
#    'FLORICULTURE, OTHER',
#    'FLOUR',
#    'FLOWER SEEDS',
#    'FLOWERING PLANTS, POTTED',
#    'FOLIAGE PLANTS',
#    'FOOD COMMODITIES',
#    'FOOD CROP TOTALS',
#    'FOOD CROP, OTHER',
#    'FOOD FISH',
#    'FOOD GRAINS',
#    'FRUIT & NUT PLANTS',
#    'FRUIT & TREE NUT TOTALS',
#    'FRUIT & TREE NUTS, OTHER',
#    'FRUIT BEARING TREES',
#    'FRUIT TOTALS',
#    'FRUIT, OTHER',
#    'FUELS',
#    'FUMIGANTS',
#    'FUNGICIDES',
#    'FUNGICIDES & OTHER',
#    'GADO',
#    'GARLIC',
#    'GEESE',
#    'GINGER ROOT',
#    'GINSENG',
#    'GOATS',
#    'GOOSEBERRIES',
#    'GOVT PROGRAM TOTALS',
#    'GOVT PROGRAMS',
#    'GRAIN',
#    'GRAIN STORAGE CAPACITY',
#    'GRAPEFRUIT',
#    'GRAPES',
#    'GRASSES',
#    'GRASSES & LEGUMES TOTALS',
#    'GRASSES & LEGUMES, OTHER',
#    'GREASE',
#    'GREENS',
#    'GROWING MEDIA',
#    'GUAR',
#    'GUAVAS',
#    'GUINEAS',
#    'HAY',
#    'HAY & HAYLAGE',
#    'HAYLAGE',
#    'HAZELNUTS',
#    'HEMP',
#    'HERBICIDES',
#    'HERBS',
#    'HERBS & SPICES',
#    'HOGS',
#    'HONEY',
#    'HOPS',
#    'HORSERADISH',
#    'HORTICULTURE TOTALS',
#    'HORTICULTURE, OTHER',
#    'ICE CREAM',
#    'IMPROVEMENT & CONSTRUCTION',
#    'INCOME, FARM RELATED',
#    'INCOME, FARM-RELATED',
#    'INCOME, NET CASH FARM',
#    'INSECTICIDES',
#    'INTEREST',
#    'INTERNET',
#    'IRRIGATION ORGANIZATIONS',
#    'JOJOBA',
#    'K-EARLY CITRUS',
#    'KAVA',
#    'KIWIFRUIT',
#    'KUMQUATS',
#    'LABOR',
#    'LAMB & MUTTON',
#    'LAND AREA',
#    'LANDLORDS',
#    'LARD',
#    'LAUPELE',
#    'LEGUMES',
#    'LEMONS',
#    'LEMONS & LIMES',
#    'LENTILS',
#    'LETTUCE',
#    'LIMES',
#    'LIVESTOCK TOTALS',
#    'LIVESTOCK, OTHER',
#    'LLAMAS',
#    'LOGANBERRIES',
#    'LOTUS ROOT',
#    'MACADAMIAS',
#    'MACHINERY',
#    'MACHINERY TOTALS',
#    'MACHINERY, OTHER',
#    'MANGOES',
#    'MAPLE SYRUP',
#    'MEAL',
#    'MEDICINE & DRUGS',
#    'MELLORINE',
#    'MELONS',
#    'MILK',
#    'MILK COOLERS',
#    'MILKING MACHINES',
#    'MILLET',
#    'MILLFEED',
#    'MINK',
#    'MINT',
#    'MISCANTHUS',
#    'MOHAIR',
#    'MOLLUSKS',
#    'MUSHROOM SPAWN',
#    'MUSHROOMS',
#    'MUSTARD',
#    'NECTARINES',
#    'NITROGEN',
#    'NON-CITRUS FRUIT & TREE NUTS TOTALS',
#    'NON-CITRUS TOTALS',
#    'NON-CITRUS, OTHER',
#    'NONFARM SECTOR',
#    'NURSERY & FLORICULTURE TOTALS',
#    'NURSERY TOTALS',
#    'NURSERY, OTHER',
#    'OATS',
#    'OIL',
#    'OIL-BEARING CROPS',
#    'OKRA',
#    'OLIVES',
#    'ONIONS',
#    'OPERATORS',
#    'OPERATORS, FIRST FOUR OPERATORS',
#    'OPERATORS, PRINCIPAL',
#    'OPERATORS, SECOND',
#    'OPERATORS, THIRD',
#    'ORANGES',
#    'ORCHARDS',
#    'ORNAMENTAL FISH',
#    'ORNAMENTAL GRASSES',
#    'ORNAMENTAL TREE SEEDLINGS',
#    'OSTRICHES',
#    'PACKING FACILITY',
#    'PALMS',
#    'PAPAYAS',
#    'PARSLEY',
#    'PARTRIDGES',
#    'PASSION FRUIT',
#    'PASTURELAND',
#    'PEACHES',
#    'PEACHES & NECTARINES',
#    'PEAFOWL',
#    'PEANUTS',
#    'PEARS',
#    'PEAS',
#    'PEAS & CARROTS',
#    'PEAS & LENTILS',
#    'PECANS',
#    'PEPPERS',
#    'PERSIMMONS',
#    'PHEASANTS',
#    'PHOSPHATE',
#    'PICKLES',
#    'PIGEONS & SQUAB',
#    'PIMIENTOS',
#    'PINEAPPLES',
#    'PISTACHIOS',
#    'PITW',
#    'PLANTAINS',
#    'PLUM-APRICOT HYBRIDS',
#    'PLUMS',
#    'PLUMS & PRUNES',
#    'POINSETTIAS',
#    'POMEGRANATES',
#    'POPCORN',
#    'PORK',
#    'POTASH',
#    'POTASH & PHOSPHATE',
#    'POTATOES',
#    'POTATOES & DRY BEANS',
#    'POULTRY BY-PRODUCT MEALS',
#    'POULTRY FATS',
#    'POULTRY TOTALS',
#    'POULTRY, OTHER',
#    'PPITW',
#    'PRACTICES',
#    'PRICE INDEX RATIO',
#    'PRODUCERS',
#    'PRODUCERS, (EXCL PRINCIPAL)',
#    'PRODUCERS, FIRST FOUR PRODUCERS',
#    'PRODUCERS, PRIMARY',
#    'PRODUCERS, PRINCIPAL',
#    'PRODUCTION ITEMS',
#    'PRODUCTION ITEMS & CONSUMER PRICE INDEX',
#    'PROPAGATIVE MATERIAL',
#    'PRUNES',
#    'PUMPKINS',
#    'PUMPS',
#    'QUAIL',
#    'QUENEPAS',
#    'RABBITS',
#    'RADISHES',
#    'RAPESEED',
#    'RASPBERRIES',
#    'RED MEAT',
#    'RENT',
#    'REPAIRS',
#    'RETURNS & ALLOWANCES',
#    'RHEAS',
#    'RHUBARB',
#    'RICE',
#    'ROOT CELERY',
#    'ROOT CROPS & TUBERS',
#    'ROOT CROPS & TUBERS, OTHER',
#    'ROOTS & TUBERS',
#    'ROOTS, OTHER',
#    'ROW CROPS',
#    'RYE',
#    'SAFFLOWER',
#    'SEEDS',
#    'SEEDS & PLANTS TOTALS',
#    'SELF PROPELLED',
#    'SESAME',
#    'SHEEP',
#    'SHEEP & GOATS TOTALS',
#    'SHERBET',
#    'SHORT TERM WOODY CROPS',
#    'SILAGE',
#    'SMALL GRAINS',
#    'SNOW',
#    'SOD',
#    'SOIL',
#    'SORGHUM',
#    'SORREL',
#    'SOURSOPS',
#    'SOYBEANS',
#    'SPECIALTY ANIMAL TOTALS',
#    'SPECIALTY ANIMALS, OTHER',
#    'SPINACH',
#    'SPORT FISH',
#    'SPRAYERS',
#    'SPROUTS',
#    'SQUASH',
#    'STARFRUIT',
#    'STRAWBERRIES',
#    'STRING TRIMMERS',
#    'SUGARBEETS',
#    'SUGARCANE',
#    'SUNFLOWER',
#    'SUPPLIES',
#    'SUPPLIES & REPAIRS',
#    'SWEET CORN',
#    'SWEET POTATOES',
#    'SWEET RICE',
#    'SWEETSOPS',
#    'SWITCHGRASS',
#    'TALLOW',
#    'TANGELOS',
#    'TANGERINES',
#    'TANIERS',
#    'TARO',
#    'TAXES',
#    'TEMPLES',
#    'TENANTS',
#    'TILLERS',
#    'TOBACCO',
#    'TOMATOES',
#    'TRACTORS',
#    'TRACTORS & SELF PROPELLED',
#    'TRANSPLANTS',
#    'TREE NUT TOTALS',
#    'TREE NUTS, OTHER',
#    'TRITICALE',
#    'TRUCKS',
#    'TRUCKS & AUTOS',
#    'TURKEYS',
#    'TURNIPS',
#    'VEAL',
#    'VEGETABLE SEEDS',
#    'VEGETABLE TOTALS',
#    'VEGETABLES, MIXED',
#    'VEGETABLES, OTHER',
#    'WALNUTS',
#    'WATER',
#    'WATER ICES',
#    'WATERCRESS',
#    'WELLS',
#    'WHEAT',
#    'WHEY',
#    'WILD RICE',
#    'WOOD CHIPPERS',
#    'WOODY ORNAMENTALS & VINES, OTHER',
#    'WOOL',
#    'YAMS',
#    'YOGURT']},
#  {'region_desc': ['11 STATES',
#    '12 STATE TOTAL',
#    '13 STATE TOTAL',
#    '15 STATE TOTAL',
#    '16 STATES',
#    '17 STATES',
#    '19 STATE TOTAL',
#    '20 STATES',
#    '21 STATE TOTAL',
#    '21 STATES',
#    '22 STATE TOTAL',
#    '23 STATES',
#    '24 STATES',
#    '26 STATES',
#    '3 STATE TOTAL',
#    '48 STATES',
#    '5 STATE TOTAL',
#    '7 STATE TOTAL',
#    '7 STATES- AZ CA CO IA KS NE TX',
#    '9 STATE TOTAL',
#    '9 STATES',
#    'AK-CHIN',
#    'ALABAMA & FLORIDA',
#    'ALABAMA & FLORIDA & NEVADA',
#    'AMERICAN SAMOA',
#    'AMERICAN SAMOA, EASTERN',
#    'AMERICAN SAMOA, EASTERN, ITUAU',
#    'AMERICAN SAMOA, EASTERN, MAOPUTASI',
#    'AMERICAN SAMOA, EASTERN, SAOLE',
#    'AMERICAN SAMOA, EASTERN, SUA',
#    'AMERICAN SAMOA, EASTERN, VAIFANUA',
#    'AMERICAN SAMOA, MANUA & SWAINS ISLAND',
#    'AMERICAN SAMOA, MANUA & SWAINS ISLAND, FALESAO',
#    'AMERICAN SAMOA, MANUA & SWAINS ISLAND, FITIUTA',
#    'AMERICAN SAMOA, MANUA & SWAINS ISLAND, OFU',
#    'AMERICAN SAMOA, MANUA & SWAINS ISLAND, OLOSEGA',
#    'AMERICAN SAMOA, MANUA & SWAINS ISLAND, TAU',
#    'AMERICAN SAMOA, WESTERN',
#    'AMERICAN SAMOA, WESTERN, LEALATAUA',
#    'AMERICAN SAMOA, WESTERN, LEASINA',
#    'AMERICAN SAMOA, WESTERN, TUALATAI',
#    'AMERICAN SAMOA, WESTERN, TUALAUTA',
#    'ANNUAL STATES',
#    'APPALACHIA',
#    'APPALACHIAN',
#    'APPALACHIAN I',
#    'APPALACHIAN II',
#    'APPALACHIANS',
#    'ATLANTIC',
#    'ATLANTIC, OTHER STATES',
#    'ATLANTIC, TOTAL',
#    'AZ OTHER',
#    'AZ YUMA/WESTERN',
#    'BAD RIVER',
#    'BLACKFEET',
#    'BOIS FORTE',
#    'BURNS PAIUTE',
#    'CA DESERT VALLEY',
#    'CA LA MO TN & WV',
#    'CA MO TN WV',
#    'CA OTHER AREA',
#    'CA TN & WV',
#    'CALIFORNIA',
#    'CENTRAL',
#    'CENTRAL STATES',
#    'CHEYENNE RIVER',
#    'CO OK',
#    'COCOPAH',
#    "COEUR D'ALENE",
#    'COLORADO RIVER',
#    'COLVILLE',
#    'CORN BELT',
#    'CORN BELT I',
#    'CORN BELT II',
#    'COTTON - SPEC STATES (4 STATE)',
#    'CROW',
#    'CROW CREEK',
#    'DELTA',
#    'DELTA STATES',
#    'E SOUTH CENTRAL',
#    'EAST NORTH CENTRAL',
#    'EASTERN',
#    'EASTERN ROCKIES',
#    'EASTERN STATES',
#    'EASTERN STATES, OTHER',
#    'FL GA SC',
#    'FL HASTINGS',
#    'FL OTHER',
#    'FLANDREAU SANTEE',
#    'FLATHEAD',
#    'FLORIDA',
#    'FOND DU LAC',
#    'FORT BELKNAP',
#    'FORT BERTHOLD',
#    'FORT HALL',
#    'FORT MCDOWELL',
#    'FORT MOJAVE',
#    'FORT PECK',
#    'FORT YUMA-QUECHAN',
#    'GILA RIVER',
#    'GUAM',
#    'HAWAII',
#    'HAY, ALFALFA - FULL PROGRAM STATES',
#    'HAY, ALFALFA - OTHER (ANNUAL) STATES',
#    'HAY, OTHER - FULL PROGRAM STATES',
#    'HAY, OTHER - OTHER (ANNUAL) STATES',
#    'HIGH PLAINS',
#    'HO-CHUNK',
#    'HOPI',
#    'HUALAPAI',
#    'IA NE',
#    'ID (INCL MALHEUR COUNTY OR)',
#    'ID 10 SW COUNTIES',
#    'ID MT',
#    'ID MT OR UT WA',
#    'ID OTHER',
#    'IDAHO & WASHINGTON',
#    'IL IN WI',
#    'ILLINOIS',
#    'IN & MO',
#    'INDIAN RIVER AREA',
#    'INTERIOR AREA',
#    'IOWA',
#    'KAIBAB PAIUTE',
#    'KANSAS',
#    'KLAMATH BASIN',
#    'KS OK & TX',
#    'KY TN',
#    'LA & MO',
#    'LA MO & TN',
#    'LAC COURTE OREILLES OJIBWA',
#    'LAC DU FLAMBEAU',
#    'LAKE',
#    'LAKE STATES',
#    'LAKE TRAVERSE',
#    'LEECH LAKE',
#    'LOWER BRULE',
#    'LOWER SIOUX',
#    'LUMMI',
#    'MD & DE',
#    'MD VA',
#    'MENOMINEE',
#    'MICHIGAN',
#    'MID CENTRAL',
#    'MIDWEST',
#    'MIDWEST, OTHER STATES',
#    'MIDWEST, TOTAL',
#    'MILLE LACS',
#    'MINNESOTA',
#    'MINNESOTA-WISCONSIN',
#    'MINOR STATES',
#    'MINOR STATES III',
#    'MISSISSIPPI BANDS OF CHOCTAW',
#    'MISSOURI',
#    'MOUNTAIN',
#    'MOUNTAIN I',
#    'MOUNTAIN II',
#    'MOUNTAIN III',
#    'NAVAJO NATION',
#    'NEW ENGLAND',
#    'NEW ENGLAND STATES',
#    'NEZ PERCE',
#    'NJ NY',
#    'NON-SPEC STATES',
#    'NORTH & EAST',
#    'NORTH AND SOUTH ATLANTIC',
#    'NORTH ATLANTIC',
#    'NORTH CAROLINA',
#    'NORTH CENTRAL',
#    'NORTH CENTRAL, OTHER STATES',
#    'NORTH DAKOTA',
#    'NORTHEAST',
#    'NORTHEAST I',
#    'NORTHEAST II',
#    'NORTHEAST, OTHER STATES',
#    'NORTHERN',
#    'NORTHERN CHEYENNE',
#    'NORTHERN MARIANA ISLANDS',
#    'NORTHERN MARIANA ISLANDS, ROTA',
#    'NORTHERN MARIANA ISLANDS, SAIPAN',
#    'NORTHERN MARIANA ISLANDS, TINIAN',
#    'NORTHERN PLAINS',
#    'NORTHWEST',
#    'NORTHWESTERN',
#    'NY LONG ISLAND',
#    'NY UPSTATE',
#    'OATS - STOCKS, NON-PUBLISHED STATES',
#    'OHIO',
#    'OLD STATE = 64',
#    'OLD STATE = 65',
#    'OMAHA',
#    'ONEIDA TRIBE OF WISCONSIN',
#    'OR & WA',
#    'OR MALHUER',
#    'OR OTHER',
#    'OR UT WA',
#    'OTHER PLACEMENT STATES',
#    'OTHER STATES',
#    'PACIFIC',
#    'PACIFIC & CA',
#    'PACIFIC NORTHWEST (ID OR WA)',
#    'PEANUTS - ANNUAL STATES',
#    'PENNSYLVANIA',
#    'PINE RIDGE',
#    'PLAINS',
#    'PLAINS, OTHER STATES',
#    'PLAINS, TOTAL',
#    'POTATOES - CO OTHER',
#    'POTATOES - CO SAN LUIS VALLEY',
#    'POTATOES - OR KLAMATH BASIN',
#    'POTATOES - OR OUTSIDE KLAMATH BASIN',
#    'PRAIRIE ISLAND COMMUNITY',
#    'PROGRAM STATES',
#    'PUBLISHED STATES',
#    'PUEBLO DE COCHITI',
#    'PUEBLO OF ISLETA',
#    'PUEBLO OF JEMEZ',
#    'PUEBLO OF SANTO DOMINGO',
#    'PUEBLO OF ZUNI',
#    'PUERTO RICO',
#    'PUERTO RICO, ARECIBO',
#    'PUERTO RICO, CAGUAS',
#    'PUERTO RICO, LARES',
#    'PUERTO RICO, MAYAGUEZ',
#    'PUERTO RICO, NARANJITO',
#    'PUERTO RICO, PONCE',
#    'PUERTO RICO, SAN GERMAN',
#    'PUERTO RICO, UTUADO',
#    'RED CLIFF',
#    'RED LAKE BAND',
#    'REGION 1 (AZ CA CO HI NV NM UT)',
#    'REGION 1 (CT IA IL IN KS MA ME MI NE NH NJ NY OH PA RI VT WI)',
#    'REGION 1 (CT ME NH VT MA RI)',
#    'REGION 1 - AZ CA ID NV OR WA',
#    'REGION 10 (AK ID OR WA)',
#    'REGION 2 (AL DE GA KY MD NC SC TN VA WV)',
#    'REGION 2 (CT DE ME MD MA NH NJ NY PA RI VT)',
#    'REGION 2 (NY NJ)',
#    'REGION 2 - NM & TX',
#    'REGION 3 (AK ID MT OR WA WY)',
#    'REGION 3 (AR FL LA MO MS NM OK TX)',
#    'REGION 3 (DE-MD PA WV VA)',
#    'REGION 3 - CO MT SD UT WY',
#    'REGION 4 (AL FL GA KY MS NC SC)',
#    'REGION 4 (CO MN MT ND NV SD UT WY)',
#    'REGION 4 (IA KS MN MO NE ND SD)',
#    'REGION 4 - IA KS MN MO NE ND OK',
#    'REGION 5 (AK ID OR WA)',
#    'REGION 5 (AL AR LA MS OK TX)',
#    'REGION 5 (IL IN MI MN OH WI)',
#    'REGION 5 - ALL OTHER STATES',
#    'REGION 6 & 7 (AZ CA HI)',
#    'REGION 6 (AR LA NM OK TX)',
#    'REGION 6 (FL GA KY NC SC TN VA WV)',
#    'REGION 7 (IA KS MO NE)',
#    'REGION 7 (IL IN MI OH WI)',
#    'REGION 8 (CO MT ND SD UT WY)',
#    'REGION 9 (AZ CA HI NV)',
#    'RICE - MONTHLY PRICE STATES (EXCL CA)',
#    'RICE - UNALLOCATED STATES',
#    "ROCKY BOY'S",
#    'ROCKY MOUNTAINS',
#    'ROSEBUD',
#    'SAC AND FOX',
#    'SALT RIVER PIMA-MARICOPA',
#    'SAN CARLOS APACHE',
#    'SANTEE SIOUX',
#    'SOKAOGON CHIPPEWA COMMUNITY',
#    'SORGHUM - STOCKS, NON-PUBLISHED STATES',
#    'SOUTH',
#    'SOUTH ATLANTIC',
#    'SOUTH CENTRAL',
#    'SOUTH CENTRAL AND WEST',
#    'SOUTH, OTHER STATES',
#    'SOUTH, TOTAL',
#    'SOUTH, WEST, PACIFIC',
#    'SOUTHEAST',
#    'SOUTHEAST & FL',
#    'SOUTHEAST/DELTA',
#    'SOUTHEASTERN',
#    'SOUTHERN',
#    'SOUTHERN PLAINS',
#    'SOUTHWEST',
#    'SOUTHWESTERN',
#    'SPEC 11-STATE',
#    'SPEC STATES',
#    'SPIRIT LAKE',
#    'SPOKANE',
#    'ST. CROIX',
#    'STANDING ROCK',
#    'STOCKBRIDGE-MUNSEE',
#    'TEXAS',
#    "TOHONO O'ODHAM",
#    'TURTLE MOUNTAIN/TRENTON INDIAN SERVICE AREA',
#    'UMATILLA',
#    'UNPUBLISHED QUARTERLY STATES',
#    'UPPER SIOUX',
#    'VA & WV',
#    'VIRGIN ISLANDS OF THE US',
#    'VIRGIN ISLANDS OF THE US, SAINT CROIX',
#    'VIRGIN ISLANDS OF THE US, SAINT JOHN & SAINT THOMAS',
#    'WA & OR',
#    'WARM SPRINGS',
#    'WEST',
#    'WEST CENTRAL',
#    'WEST COAST',
#    'WEST NORTH CENTRAL',
#    'WEST, OTHER STATES',
#    'WEST, TOTAL',
#    'WESTERN STATES',
#    'WESTERN STATES, OTHER',
#    'WHEAT, DURUM - ANNUAL STATES',
#    'WHEAT, SPRING - ANNUAL STATES',
#    'WHITE EARTH',
#    'WIND RIVER',
#    'WINNEBAGO',
#    'YAKAMA',
#    'YANKTON']},
#  {'domaincat_desc': ['AREA BEARING & NON-BEARING: (0.1 TO 0.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (0.1 TO 14.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (0.1 TO 4.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (0.1 TO 99.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (1,000 OR MORE ACRES)',
#    'AREA BEARING & NON-BEARING: (1,000 TO 1,499 ACRES)',
#    'AREA BEARING & NON-BEARING: (1,000 TO 1,999 ACRES)',
#    'AREA BEARING & NON-BEARING: (1,500 OR MORE ACRES)',
#    'AREA BEARING & NON-BEARING: (1.0 TO 4.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (100 OR MORE ACRES)',
#    'AREA BEARING & NON-BEARING: (100 TO 249 ACRES)',
#    'AREA BEARING & NON-BEARING: (15.0 TO 24.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (15.0 TO 99.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (2,000 TO 2,999 ACRES)',
#    'AREA BEARING & NON-BEARING: (25.0 TO 49.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (25.0 TO 99.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (250 OR MORE ACRES)',
#    'AREA BEARING & NON-BEARING: (250 TO 499 ACRES)',
#    'AREA BEARING & NON-BEARING: (3,000 OR MORE ACRES)',
#    'AREA BEARING & NON-BEARING: (5.0 TO 14.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (5.0 TO 24.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (50.0 TO 99.9 ACRES)',
#    'AREA BEARING & NON-BEARING: (500 OR MORE ACRES)',
#    'AREA BEARING & NON-BEARING: (500 TO 749 ACRES)',
#    'AREA BEARING & NON-BEARING: (750 TO 999 ACRES)',
#    'AREA CROPLAND, HARVESTED: (1,000 TO 1,999 ACRES)',
#    'AREA CROPLAND, HARVESTED: (10.0 TO 49.9 ACRES)',
#    'AREA CROPLAND, HARVESTED: (100 PCT ON RESERVATION)',
#    'AREA CROPLAND, HARVESTED: (100 TO 139 ACRES)',
#    'AREA CROPLAND, HARVESTED: (140 TO 179 ACRES)',
#    'AREA CROPLAND, HARVESTED: (180 TO 219 ACRES)',
#    'AREA CROPLAND, HARVESTED: (2,000 OR MORE ACRES)',
#    'AREA CROPLAND, HARVESTED: (2,000 TO 4,999 ACRES)',
#    'AREA CROPLAND, HARVESTED: (220 TO 259 ACRES)',
#    'AREA CROPLAND, HARVESTED: (25 TO 49 PCT ON RESERVATION)',
#    'AREA CROPLAND, HARVESTED: (260 TO 499 ACRES)',
#    'AREA CROPLAND, HARVESTED: (5,000 OR MORE ACRES)',
#    'AREA CROPLAND, HARVESTED: (50 TO 74 PCT ON RESERVATION)',
#    'AREA CROPLAND, HARVESTED: (50.0 TO 69.9 ACRES)',
#    'AREA CROPLAND, HARVESTED: (500 TO 999 ACRES)',
#    'AREA CROPLAND, HARVESTED: (70.0 TO 99.9 ACRES)',
#    'AREA CROPLAND, HARVESTED: (75 TO 99 PCT ON RESERVATION)',
#    'AREA CROPLAND, HARVESTED: (ANY)',
#    'AREA CROPLAND, HARVESTED: (LESS THAN 10.0 ACRES)',
#    'AREA CROPLAND, HARVESTED: (LESS THAN 25 PCT ON RESERVATION)',
#    'AREA GROWN: (0.1 TO 0.9 ACRES)',
#    'AREA GROWN: (1.0 TO 4.9 ACRES)',
#    'AREA GROWN: (100 OR MORE ACRES)',
#    'AREA GROWN: (15.0 TO 24.9 ACRES)',
#    'AREA GROWN: (25.0 TO 49.9 ACRES)',
#    'AREA GROWN: (5.0 TO 14.9 ACRES)',
#    'AREA GROWN: (50.0 TO 99.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 0.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 14.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 4.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 99.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (1,000 OR MORE ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (1,000 TO 1,999 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (1.0 TO 4.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (100 OR MORE ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (100 TO 249 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (15.0 TO 24.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (15.0 TO 99.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (2,000 TO 2,999 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (25.0 TO 49.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (25.0 TO 99.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (250 OR MORE ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (250 TO 499 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (3,000 OR MORE ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (3,000 TO 4,999 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (5,000 OR MORE ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (5.0 TO 14.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (5.0 TO 24.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (50.0 TO 99.9 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (500 OR MORE ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (500 TO 749 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (500 TO 999 ACRES)',
#    'AREA HARVESTED, FRESH MARKET & PROCESSING: (750 TO 999 ACRES)',
#    'AREA HARVESTED: (0.1 TO 0.9 ACRES)',
#    'AREA HARVESTED: (0.1 TO 1.9 ACRES)',
#    'AREA HARVESTED: (0.1 TO 14.9 ACRES)',
#    'AREA HARVESTED: (0.1 TO 4.9 ACRES)',
#    'AREA HARVESTED: (0.1 TO 99.9 ACRES)',
#    'AREA HARVESTED: (1,000 OR MORE ACRES)',
#    'AREA HARVESTED: (1,000 TO 1,999 ACRES)',
#    'AREA HARVESTED: (1.0 TO 1.9 ACRES)',
#    'AREA HARVESTED: (1.0 TO 14.9 ACRES)',
#    'AREA HARVESTED: (1.0 TO 24.9 ACRES)',
#    'AREA HARVESTED: (1.0 TO 4.9 ACRES)',
#    'AREA HARVESTED: (1.0 TO 49.9 ACRES)',
#    'AREA HARVESTED: (1.0 TO 9.9 ACRES)',
#    'AREA HARVESTED: (10 OR MORE ACRES)',
#    'AREA HARVESTED: (10.0 TO 19.9 ACRES)',
#    'AREA HARVESTED: (10.0 TO 24.9 ACRES)',
#    'AREA HARVESTED: (100 OR MORE ACRES)',
#    'AREA HARVESTED: (100 TO 149 ACRES)',
#    'AREA HARVESTED: (100 TO 199 ACRES)',
#    'AREA HARVESTED: (100 TO 249 ACRES)',
#    'AREA HARVESTED: (15.0 TO 24.9 ACRES)',
#    'AREA HARVESTED: (15.0 TO 29.9 ACRES)',
#    'AREA HARVESTED: (15.0 TO 49.9 ACRES)',
#    'AREA HARVESTED: (150 TO 249 ACRES)',
#    'AREA HARVESTED: (2,000 OR MORE ACRES)',
#    'AREA HARVESTED: (2,000 TO 2,999 ACRES)',
#    'AREA HARVESTED: (2.0 TO 14.9 ACRES)',
#    'AREA HARVESTED: (2.0 TO 2.9 ACRES)',
#    'AREA HARVESTED: (20.0 TO 29.9 ACRES)',
#    'AREA HARVESTED: (200 TO 499 ACRES)',
#    'AREA HARVESTED: (25 OR MORE ACRES)',
#    'AREA HARVESTED: (25.0 TO 49.9 ACRES)',
#    'AREA HARVESTED: (25.0 TO 99.9 ACRES)',
#    'AREA HARVESTED: (250 OR MORE ACRES)',
#    'AREA HARVESTED: (250 TO 399 ACRES)',
#    'AREA HARVESTED: (250 TO 499 ACRES)',
#    'AREA HARVESTED: (3,000 TO 4,999 ACRES)',
#    'AREA HARVESTED: (3.0 TO 4.9 ACRES)',
#    'AREA HARVESTED: (30.0 TO 49.9 ACRES)',
#    'AREA HARVESTED: (400 OR MORE ACRES)',
#    'AREA HARVESTED: (400 TO 749 ACRES)',
#    'AREA HARVESTED: (5,000 OR MORE ACRES)',
#    'AREA HARVESTED: (5.0 TO 14.9 ACRES)',
#    'AREA HARVESTED: (5.0 TO 24.9 ACRES)',
#    'AREA HARVESTED: (5.0 TO 9.9 ACRES)',
#    'AREA HARVESTED: (50 OR MORE ACRES)',
#    'AREA HARVESTED: (50 TO 249 ACRES)',
#    'AREA HARVESTED: (50 TO 499 ACRES)',
#    'AREA HARVESTED: (50.0 TO 74.9 ACRES)',
#    'AREA HARVESTED: (50.0 TO 99.9 ACRES)',
#    'AREA HARVESTED: (500 OR MORE ACRES)',
#    'AREA HARVESTED: (500 TO 999 ACRES)',
#    'AREA HARVESTED: (75.0 TO 99.9 ACRES)',
#    'AREA HARVESTED: (750 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (0.1 TO 0.9 ACRES)',
#    'AREA IN PRODUCTION: (0.1 TO 14.9 ACRES)',
#    'AREA IN PRODUCTION: (0.1 TO 4.9 ACRES)',
#    'AREA IN PRODUCTION: (0.1 TO 99.9 ACRES)',
#    'AREA IN PRODUCTION: (1 TO 999 SQ FT)',
#    'AREA IN PRODUCTION: (1,000 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (1,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (1,000 TO 1,999 ACRES)',
#    'AREA IN PRODUCTION: (1,000 TO 1,999 SQ FT)',
#    'AREA IN PRODUCTION: (1,000,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (1.0 TO 2.9 ACRES)',
#    'AREA IN PRODUCTION: (1.0 TO 4.9 ACRES)',
#    'AREA IN PRODUCTION: (1.0 TO 9.9 ACRES)',
#    'AREA IN PRODUCTION: (10,000 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (10,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (10,000 TO 19,999 SQ FT)',
#    'AREA IN PRODUCTION: (10.0 TO 19.9 ACRES)',
#    'AREA IN PRODUCTION: (10.0 TO 49.9 ACRES)',
#    'AREA IN PRODUCTION: (100 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (100 TO 249 ACRES)',
#    'AREA IN PRODUCTION: (100,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (100,000 TO 199,999 SQ FT)',
#    'AREA IN PRODUCTION: (15.0 TO 24.9 ACRES)',
#    'AREA IN PRODUCTION: (15.0 TO 99.9 ACRES)',
#    'AREA IN PRODUCTION: (2,000 TO 2,999 ACRES)',
#    'AREA IN PRODUCTION: (2,000 TO 2,999 SQ FT)',
#    'AREA IN PRODUCTION: (2,000 TO 4,999 SQ FT)',
#    'AREA IN PRODUCTION: (20,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (20,000 TO 39,999 SQ FT)',
#    'AREA IN PRODUCTION: (20,000 TO 49,999 SQ FT)',
#    'AREA IN PRODUCTION: (20.0 TO 49.9 ACRES)',
#    'AREA IN PRODUCTION: (200,000 TO 499,999 SQ FT)',
#    'AREA IN PRODUCTION: (25.0 TO 49.9 ACRES)',
#    'AREA IN PRODUCTION: (25.0 TO 99.9 ACRES)',
#    'AREA IN PRODUCTION: (250 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (250 TO 499 ACRES)',
#    'AREA IN PRODUCTION: (3,000 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (3,000 TO 3,999 SQ FT)',
#    'AREA IN PRODUCTION: (3,000 TO 4,999 ACRES)',
#    'AREA IN PRODUCTION: (3.0 TO 4.9 ACRES)',
#    'AREA IN PRODUCTION: (4,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (4,000 TO 5,999 SQ FT)',
#    'AREA IN PRODUCTION: (40,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (5,000 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (5,000 TO 9,999 ACRES)',
#    'AREA IN PRODUCTION: (5,000 TO 9,999 SQ FT)',
#    'AREA IN PRODUCTION: (5.0 TO 14.9 ACRES)',
#    'AREA IN PRODUCTION: (5.0 TO 24.9 ACRES)',
#    'AREA IN PRODUCTION: (5.0 TO 9.9 ACRES)',
#    'AREA IN PRODUCTION: (50,000 OR MORE SQ FT)',
#    'AREA IN PRODUCTION: (50,000 TO 99,999 SQ FT)',
#    'AREA IN PRODUCTION: (50.0 TO 99.9 ACRES)',
#    'AREA IN PRODUCTION: (500 OR MORE ACRES)',
#    'AREA IN PRODUCTION: (500 TO 749 ACRES)',
#    'AREA IN PRODUCTION: (500,000 TO 999,999 SQ FT)',
#    'AREA IN PRODUCTION: (6,000 TO 9,999 SQ FT)',
#    'AREA IN PRODUCTION: (750 TO 999 ACRES)',
#    'AREA IRRIGATED, BEARING & NON-BEARING: (0.1 TO 4.9 ACRES)',
#    'AREA IRRIGATED, BEARING & NON-BEARING: (100 OR MORE ACRES)',
#    'AREA IRRIGATED, BEARING & NON-BEARING: (15.0 TO 49.9 ACRES)',
#    'AREA IRRIGATED, BEARING & NON-BEARING: (5.0 TO 14.9 ACRES)',
#    'AREA IRRIGATED, BEARING & NON-BEARING: (50.0 TO 99.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (0.1 TO 14.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (0.1 TO 4.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (1,000 OR MORE ACRES)',
#    'AREA IRRIGATED, HARVESTED: (1.0 TO 24.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (1.0 TO 49.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (1.0 TO 99.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (100 OR MORE ACRES)',
#    'AREA IRRIGATED, HARVESTED: (100 TO 249 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (15.0 TO 99.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (25.0 TO 49.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (250 OR MORE ACRES)',
#    'AREA IRRIGATED, HARVESTED: (250 TO 449 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (250 TO 499 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (5.0 TO 24.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (50.0 TO 99.9 ACRES)',
#    'AREA IRRIGATED, HARVESTED: (500 OR MORE ACRES)',
#    'AREA IRRIGATED, HARVESTED: (500 TO 999 ACRES)',
#    'AREA IRRIGATED, IN PRODUCTION: (0.1 TO 4.9 ACRES)',
#    'AREA IRRIGATED, IN PRODUCTION: (100 TO 249 ACRES)',
#    'AREA IRRIGATED, IN PRODUCTION: (25.0 TO 99.9 ACRES)',
#    'AREA IRRIGATED, IN PRODUCTION: (250 OR MORE ACRES)',
#    'AREA IRRIGATED, IN PRODUCTION: (5.0 TO 24.9 ACRES)',
#    'AREA IRRIGATED: (1,000 OR MORE ACRES)',
#    'AREA IRRIGATED: (1,000 TO 1,999 ACRES)',
#    'AREA IRRIGATED: (1.0 TO 49.9 ACRES)',
#    'AREA IRRIGATED: (1.0 TO 9.9 ACRES)',
#    'AREA IRRIGATED: (10.0 TO 49.9 ACRES)',
#    'AREA IRRIGATED: (100 TO 199 ACRES)',
#    'AREA IRRIGATED: (2,000 OR MORE ACRES)',
#    'AREA IRRIGATED: (200 TO 499 ACRES)',
#    'AREA IRRIGATED: (50.0 TO 99.9 ACRES)',
#    'AREA IRRIGATED: (500 TO 999 ACRES)',
#    'AREA OPERATED: (1 TO 9 CUERDAS)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND ORGANIZATION: (TAX PURPOSES, CORPORATION)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND ORGANIZATION: (TAX PURPOSES, FAMILY & INDIVIDUAL)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND ORGANIZATION: (TAX PURPOSES, INSTITUTIONAL & RESEARCH & RESERVATION & OTHER)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND ORGANIZATION: (TAX PURPOSES, PARTNERSHIP)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND TENURE: (FULL OWNER)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND TENURE: (PART OWNER)',
#    'AREA OPERATED: (1 TO 9 CUERDAS) AND TENURE: (TENANT)',
#    'AREA OPERATED: (1,000 OR MORE ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA BEARING & NON-BEARING: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA BEARING & NON-BEARING: (100 TO 249 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA BEARING & NON-BEARING: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA BEARING & NON-BEARING: (250 OR MORE ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA BEARING & NON-BEARING: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA CROPLAND, HARVESTED: (ANY)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (100 TO 249 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (250 OR MORE ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (0.1 TO 0.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (1,000 TO 1,999 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (1.0 TO 1.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (1.0 TO 49.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (10.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (100 TO 199 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (2.0 TO 2.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (200 TO 499 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (25 OR MORE ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (250 TO 499 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (3.0 TO 4.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (5.0 TO 9.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (50.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (500 OR MORE ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA HARVESTED: (500 TO 999 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA IN PRODUCTION: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA IN PRODUCTION: (100 TO 249 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA IN PRODUCTION: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA IN PRODUCTION: (250 OR MORE ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND AREA IN PRODUCTION: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND CHEMICAL, FUNGICIDE: (TOTAL)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND CHEMICAL, HERBICIDE: (TOTAL)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND CHEMICAL, INSECTICIDE: (EXCL NEMATICIDES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND CHEMICAL, INSECTICIDE: (NEMATICIDES)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND CHEMICAL, OTHER: (TOTAL)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (1,000 TO 2,499 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (1,000,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (1,000,000 TO 2,499,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (100,000 TO 249,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (2,500 TO 4,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (2,500,000 TO 4,999,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (250,000 TO 499,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (5,000,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (50,000 TO 99,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (500,000 TO 999,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ECONOMIC CLASS: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (1,000 TO 4,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (100,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (100,000 TO 249,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (25,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (25,000 TO 99,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (250,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (5,000 TO 24,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (50,000 TO 99,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND EXPENSE: (LESS THAN 5,000 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND FERTILIZER: (MANURE)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND FERTILIZER: (ORGANIC)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND FERTILIZER: (TOTAL)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLD SIZE: (1 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLD SIZE: (2 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLD SIZE: (3 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLD SIZE: (4 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLD SIZE: (5 OR MORE PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (1 HOUSEHOLDS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (2 HOUSEHOLDS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (3 HOUSEHOLDS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (4 HOUSEHOLDS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (5 OR MORE HOUSEHOLDS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF BEEF COWS: (1 TO 9 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF BEEF COWS: (10 TO 49 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF BEEF COWS: (100 TO 199 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF BEEF COWS: (200 TO 499 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF BEEF COWS: (50 TO 99 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF BEEF COWS: (500 OR MORE HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (1 TO 9 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (10 TO 49 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (100 TO 199 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (200 TO 499 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (50 TO 99 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (500 OR MORE HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF HOGS: (1 TO 24 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF HOGS: (100 TO 199 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF HOGS: (200 TO 499 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF HOGS: (25 TO 49 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF HOGS: (50 TO 99 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF HOGS: (500 OR MORE HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF MILK COWS: (1 TO 9 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF MILK COWS: (10 TO 49 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF MILK COWS: (100 TO 199 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF MILK COWS: (200 TO 499 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF MILK COWS: (50 TO 99 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY OF MILK COWS: (500 OR MORE HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (1 TO 399 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (10,000 TO 19,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (100,000 OR MORE HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (20,000 TO 49,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (3,200 TO 9,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (400 TO 3,199 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND INVENTORY: (50,000 TO 99,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND IRRIGATION STATUS: (ANY ON OPERATION)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND LABOR: (INCL HIRED WORKERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND LABOR: (ONLY CONTRACT)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1111)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1112)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1113)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1114)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1119)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (11191)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (11192)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (11193 & 11194 & 11199)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (112111)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (112112)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (11212)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1122)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1123)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1124)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NAICS CLASSIFICATION: (1125 & 1129)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET GAIN: (1,000 TO 4,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET GAIN: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET GAIN: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET GAIN: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET GAIN: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET GAIN: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET LOSS: (1,000 TO 4,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET LOSS: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET LOSS: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET LOSS: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET LOSS: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND NET LOSS: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (100 PCT FROM FARMING)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (25 TO 49 PCT FROM FARMING)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (50 TO 74 PCT FROM FARMING)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (75 TO 99 PCT FROM FARMING)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (LESS THAN 25 PCT FROM FARMING)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (1 FEMALE OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (1 OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (2 FEMALE OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (2 OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (3 FEMALE OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (3 OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (4 FEMALE OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (4 OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (5 OR MORE FEMALE OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND OPERATORS: (5 OR MORE OPERATORS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND ORGANIC STATUS: (NOP USDA CERTIFIED & EXEMPT)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (1 FEMALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (1 MALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (1 PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (2 FEMALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (2 MALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (2 PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (3 FEMALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (3 MALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (3 PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (4 FEMALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (4 MALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (4 PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (5 OR MORE FEMALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (5 OR MORE MALE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND PRODUCERS: (5 OR MORE PRODUCERS)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES & DISTRIBUTION: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES OF CATTLE, INCL CALVES: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES OF HOGS: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES: (1 TO 1,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES: (100,000 OR MORE HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES: (2,000 TO 59,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES: (50,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND SALES: (60,000 TO 99,999 HEAD)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND TENURE: (FULL OWNER)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND TENURE: (PART OWNER)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND TENURE: (TENANT)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (1,000,000 TO 1,999,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (10,000 TO 19,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (10,000,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (100,000 TO 199,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (2,000,000 TO 4,999,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (20,000 TO 49,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (200,000 TO 499,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (5,000,000 TO 9,999,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (50,000 TO 99,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (500,000 OR MORE $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (500,000 TO 999,999 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (LESS THAN 5,000 $)',
#    'AREA OPERATED: (1,000 TO 1,999 ACRES) AND VALUE: (LESS THAN 50,000 $)',
#    'AREA OPERATED: (1.0 TO 2.0 ACRES)',
#    'AREA OPERATED: (1.0 TO 2.0 ACRES) AND TENURE: (FULL OWNER)',
#    'AREA OPERATED: (1.0 TO 2.0 ACRES) AND TENURE: (OWNER)',
#    'AREA OPERATED: (1.0 TO 2.0 ACRES) AND TENURE: (PART OWNER)',
#    'AREA OPERATED: (1.0 TO 2.0 ACRES) AND TENURE: (TENANT)',
#    'AREA OPERATED: (1.0 TO 49.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 49.9 ACRES) AND IRRIGATION STATUS: (ANY ON OPERATION)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA BEARING & NON-BEARING: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA BEARING & NON-BEARING: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA CROPLAND, HARVESTED: (ANY)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (0.1 TO 0.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (1.0 TO 1.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (1.0 TO 49.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (2.0 TO 2.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (3.0 TO 4.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA HARVESTED: (5.0 TO 9.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA IN PRODUCTION: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND AREA IN PRODUCTION: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND CHEMICAL, FUNGICIDE: (TOTAL)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND CHEMICAL, HERBICIDE: (TOTAL)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND CHEMICAL, INSECTICIDE: (EXCL NEMATICIDES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND CHEMICAL, INSECTICIDE: (NEMATICIDES)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND CHEMICAL, OTHER: (TOTAL)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (1,000 TO 2,499 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (1,000,000 OR MORE $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (1,000,000 TO 2,499,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (100,000 TO 249,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (2,500 TO 4,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (2,500,000 TO 4,999,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (250,000 TO 499,999 $)',
#    'AREA OPERATED: (1.0 TO 9.9 ACRES) AND ECONOMIC CLASS: (5,000 TO 9,999 $)',
# ...
#    'AREA OPERATED: (100 OR MORE ACRES) AND TENURE: (PART OWNER)',
#    'AREA OPERATED: (100 OR MORE ACRES) AND TENURE: (TENANT)',
#    'AREA OPERATED: (100 OR MORE CUERDAS)',
#    'AREA OPERATED: (100 PCT ON RESERVATION)',
#    'AREA OPERATED: (100 TO 139 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA BEARING & NON-BEARING: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA BEARING & NON-BEARING: (100 TO 249 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA BEARING & NON-BEARING: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA BEARING & NON-BEARING: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA CROPLAND, HARVESTED: (ANY)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (100 TO 249 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED, FRESH MARKET & PROCESSING: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (0.1 TO 0.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (1.0 TO 1.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (1.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (1.0 TO 49.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (10.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (100 TO 199 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (100 TO 249 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (2.0 TO 2.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (25 OR MORE ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (3.0 TO 4.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (5.0 TO 9.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA HARVESTED: (50.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA IN PRODUCTION: (0.1 TO 4.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA IN PRODUCTION: (100 TO 249 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA IN PRODUCTION: (25.0 TO 99.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND AREA IN PRODUCTION: (5.0 TO 24.9 ACRES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND CHEMICAL, FUNGICIDE: (TOTAL)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND CHEMICAL, HERBICIDE: (TOTAL)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND CHEMICAL, INSECTICIDE: (EXCL NEMATICIDES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND CHEMICAL, INSECTICIDE: (NEMATICIDES)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND CHEMICAL, OTHER: (TOTAL)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (1,000 TO 2,499 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (1,000,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (1,000,000 TO 2,499,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (100,000 TO 249,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (2,500 TO 4,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (2,500,000 TO 4,999,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (250,000 TO 499,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (5,000,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (50,000 TO 99,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (500,000 TO 999,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ECONOMIC CLASS: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (1,000 TO 4,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (100,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (100,000 TO 249,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (25,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (25,000 TO 99,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (250,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (5,000 TO 24,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (50,000 TO 99,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND EXPENSE: (LESS THAN 5,000 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND FERTILIZER: (MANURE)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND FERTILIZER: (ORGANIC)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND FERTILIZER: (TOTAL)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLD SIZE: (1 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLD SIZE: (2 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLD SIZE: (3 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLD SIZE: (4 PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLD SIZE: (5 OR MORE PERSONS LIVING IN HOUSEHOLD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (1 HOUSEHOLDS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (2 HOUSEHOLDS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (3 HOUSEHOLDS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (4 HOUSEHOLDS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND HOUSEHOLDS SHARING NET INCOME: (5 OR MORE HOUSEHOLDS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF BEEF COWS: (1 TO 9 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF BEEF COWS: (10 TO 49 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF BEEF COWS: (100 TO 199 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF BEEF COWS: (200 TO 499 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF BEEF COWS: (50 TO 99 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF BEEF COWS: (500 OR MORE HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (1 TO 9 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (10 TO 49 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (100 TO 199 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (200 TO 499 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (50 TO 99 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF CATTLE, INCL CALVES: (500 OR MORE HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF HOGS: (1 TO 24 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF HOGS: (100 TO 199 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF HOGS: (200 TO 499 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF HOGS: (25 TO 49 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF HOGS: (50 TO 99 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF HOGS: (500 OR MORE HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF MILK COWS: (1 TO 9 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF MILK COWS: (10 TO 49 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF MILK COWS: (100 TO 199 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF MILK COWS: (200 TO 499 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF MILK COWS: (50 TO 99 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY OF MILK COWS: (500 OR MORE HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (1 TO 399 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (10,000 TO 19,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (100,000 OR MORE HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (20,000 TO 49,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (3,200 TO 9,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (400 TO 3,199 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND INVENTORY: (50,000 TO 99,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND IRRIGATION STATUS: (ANY ON OPERATION)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND LABOR: (INCL HIRED WORKERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND LABOR: (ONLY CONTRACT)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1111)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1112)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1113)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1114)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1119)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (11191)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (11192)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (11193 & 11194 & 11199)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (112111)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (112112)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (11212)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1122)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1123)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1124)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NAICS CLASSIFICATION: (1125 & 1129)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET GAIN: (1,000 TO 4,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET GAIN: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET GAIN: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET GAIN: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET GAIN: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET GAIN: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET LOSS: (1,000 TO 4,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET LOSS: (10,000 TO 24,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET LOSS: (25,000 TO 49,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET LOSS: (5,000 TO 9,999 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET LOSS: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND NET LOSS: (LESS THAN 1,000 $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (100 PCT FROM FARMING)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (25 TO 49 PCT FROM FARMING)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (50 TO 74 PCT FROM FARMING)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (75 TO 99 PCT FROM FARMING)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS, PRINCIPAL, HOUSEHOLD INCOME: (LESS THAN 25 PCT FROM FARMING)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (1 FEMALE OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (1 OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (2 FEMALE OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (2 OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (3 FEMALE OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (3 OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (4 FEMALE OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (4 OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (5 OR MORE FEMALE OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND OPERATORS: (5 OR MORE OPERATORS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND ORGANIC STATUS: (NOP USDA CERTIFIED & EXEMPT)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (1 FEMALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (1 MALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (1 PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (2 FEMALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (2 MALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (2 PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (3 FEMALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (3 MALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (3 PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (4 FEMALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (4 MALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (4 PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (5 OR MORE FEMALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (5 OR MORE MALE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND PRODUCERS: (5 OR MORE PRODUCERS)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES & DISTRIBUTION: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES OF CATTLE, INCL CALVES: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES OF HOGS: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES: (1 TO 1,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES: (100,000 OR MORE HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES: (2,000 TO 59,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES: (50,000 OR MORE $)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND SALES: (60,000 TO 99,999 HEAD)',
#    'AREA OPERATED: (100 TO 139 ACRES) AND TENURE: (FULL OWNER)',
#    ...]},
#  {'year': ['1850',
#    '1860',
#    '1866',
#    '1867',
#    '1868',
#    '1869',
#    '1870',
#    '1871',
#    '1872',
#    '1873',
#    '1874',
#    '1875',
#    '1876',
#    '1877',
#    '1878',
#    '1879',
#    '1880',
#    '1881',
#    '1882',
#    '1883',
#    '1884',
#    '1885',
#    '1886',
#    '1887',
#    '1888',
#    '1889',
#    '1890',
#    '1891',
#    '1892',
#    '1893',
#    '1894',
#    '1895',
#    '1896',
#    '1897',
#    '1898',
#    '1899',
#    '1900',
#    '1901',
#    '1902',
#    '1903',
#    '1904',
#    '1905',
#    '1906',
#    '1907',
#    '1908',
#    '1909',
#    '1910',
#    '1911',
#    '1912',
#    '1913',
#    '1914',
#    '1915',
#    '1916',
#    '1917',
#    '1918',
#    '1919',
#    '1920',
#    '1921',
#    '1922',
#    '1923',
#    '1924',
#    '1925',
#    '1926',
#    '1927',
#    '1928',
#    '1929',
#    '1930',
#    '1931',
#    '1932',
#    '1933',
#    '1934',
#    '1935',
#    '1936',
#    '1937',
#    '1938',
#    '1939',
#    '1940',
#    '1941',
#    '1942',
#    '1943',
#    '1944',
#    '1945',
#    '1946',
#    '1947',
#    '1948',
#    '1949',
#    '1950',
#    '1951',
#    '1952',
#    '1953',
#    '1954',
#    '1955',
#    '1956',
#    '1957',
#    '1958',
#    '1959',
#    '1960',
#    '1961',
#    '1962',
#    '1963',
#    '1964',
#    '1965',
#    '1966',
#    '1967',
#    '1968',
#    '1969',
#    '1970',
#    '1971',
#    '1972',
#    '1973',
#    '1974',
#    '1975',
#    '1976',
#    '1977',
#    '1978',
#    '1979',
#    '1980',
#    '1981',
#    '1982',
#    '1983',
#    '1984',
#    '1985',
#    '1986',
#    '1987',
#    '1988',
#    '1989',
#    '1990',
#    '1991',
#    '1992',
#    '1993',
#    '1994',
#    '1995',
#    '1996',
#    '1997',
#    '1998',
#    '1999',
#    '2000',
#    '2001',
#    '2002',
#    '2003',
#    '2004',
#    '2005',
#    '2006',
#    '2007',
#    '2008',
#    '2009',
#    '2010',
#    '2011',
#    '2012',
#    '2013',
#    '2014',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023']}]

# %%
sector_desc
# Out:
# {'sector_desc': ['ANIMALS & PRODUCTS',
#   'CROPS',
#   'DEMOGRAPHICS',
#   'ECONOMICS',
#   'ENVIRONMENTAL']}

# %%
data_url='https://quickstats.nass.usda.gov/api/api_GET/?key='+usda_api_key 
commodity_list=['CORN','APPLES','PEACHES','BANANAS','APRICOTS','CHERRIES','GRAPES','NECTARINES','LEMONS']
state_list=['CA','IA','NE','TX','IL','KS','MN','IN','NC','WI']

def get_api_results(stateList):
    
    url=data_url+'&source_desc=SURVEY&'+ \
                 '&sector_desc=CROPS&'+ \
                 '&group_desc%3DFRUIT%20TREE%20NUTS'+ \
                 'statisticcat_desc%3DAREA%20OPERATED&'+\
                 'unit_desc=ACRES&'+ \
                 'freq_desc=ANNUAL&'+ \
                 'reference_period_desc=YEAR&'+ \
                 'year__GE=1997&'+ \
                 'agg_level_desc=STATE&'
    
    for state in stateList:
        url=url+'state_alpha='+state+'&'
           
    
    url=url+'format=JSON'
    results_json = requests.get(url).json()
    return results_json



results=get_api_results(state_list)
results_df=pd.DataFrame(results['data'])
results_df.head()
len(results_df),len(results_df[results_df['Value'].str.contains('D')]),len(results_df[results_df['short_desc'].str.contains('ACERS')])
# Out:
# https://quickstats.nass.usda.gov/api/api_GET/?key=48BE989D-D0C4-35F1-91A7-6D301038E6AA&source_desc=SURVEY&&sector_desc=CROPS&&group_desc%3DFRUIT%20TREE%20NUTSstatisticcat_desc%3DAREA%20OPERATED&unit_desc=ACRES&freq_desc=ANNUAL&reference_period_desc=YEAR&year__GE=1997&agg_level_desc=STATE&state_alpha=CA&state_alpha=IA&state_alpha=NE&state_alpha=TX&state_alpha=IL&state_alpha=KS&state_alpha=MN&state_alpha=IN&state_alpha=NC&state_alpha=WI&format=JSON
# (18721, 416, 0)

# %%
results_df.head()
# Out:
#   end_code   group_desc domain_desc state_alpha state_fips_code county_ansi  \
# 0       00  FIELD CROPS       TOTAL          CA              06
# 1       00  FIELD CROPS       TOTAL          CA              06
# 2       00  FIELD CROPS       TOTAL          CA              06
# 3       00  FIELD CROPS       TOTAL          CA              06
# 4       00  FIELD CROPS       TOTAL          CA              06
#
#   domaincat_desc watershed_code commodity_desc   class_desc  ... county_code  \
# 0  NOT SPECIFIED       00000000         BARLEY  ALL CLASSES  ...
# 1  NOT SPECIFIED       00000000         BARLEY  ALL CLASSES  ...
# 2  NOT SPECIFIED       00000000         BARLEY  ALL CLASSES  ...
# 3  NOT SPECIFIED       00000000         BARLEY  ALL CLASSES  ...
# 4  NOT SPECIFIED       00000000         BARLEY  ALL CLASSES  ...
#
#   reference_period_desc   Value asd_desc  year agg_level_desc  \
# 0                  YEAR  19,000           2022          STATE
# 1                  YEAR  13,000           2021          STATE
# 2                  YEAR  33,000           2020          STATE
# 3                  YEAR  47,000           2019          STATE
# 4                  YEAR  26,000           2018          STATE
#
#         prodn_practice_desc congr_district_code sector_desc  \
# 0  ALL PRODUCTION PRACTICES                           CROPS
# 1  ALL PRODUCTION PRACTICES                           CROPS
# 2  ALL PRODUCTION PRACTICES                           CROPS
# 3  ALL PRODUCTION PRACTICES                           CROPS
# 4  ALL PRODUCTION PRACTICES                           CROPS
#
#                  short_desc
# 0  BARLEY - ACRES HARVESTED
# 1  BARLEY - ACRES HARVESTED
# 2  BARLEY - ACRES HARVESTED
# 3  BARLEY - ACRES HARVESTED
# 4  BARLEY - ACRES HARVESTED
#
# [5 rows x 39 columns]

# %%
results_col=results_df.columns
results_col
# Out:
# Index(['end_code', 'group_desc', 'domain_desc', 'state_alpha',
#        'state_fips_code', 'county_ansi', 'domaincat_desc', 'watershed_code',
#        'commodity_desc', 'class_desc', 'freq_desc', 'week_ending',
#        'state_ansi', 'statisticcat_desc', 'watershed_desc', 'source_desc',
#        'CV (%)', 'asd_code', 'load_time', 'state_name', 'country_code',
#        'zip_5', 'util_practice_desc', 'unit_desc', 'region_desc',
#        'country_name', 'county_name', 'location_desc', 'begin_code',
#        'county_code', 'reference_period_desc', 'Value', 'asd_desc', 'year',
#        'agg_level_desc', 'prodn_practice_desc', 'congr_district_code',
#        'sector_desc', 'short_desc'],
#       dtype='object')

# %%
results_df['class_desc'].unique()
# Out:
# array(['ALL CLASSES', 'DRY EDIBLE, (EXCL CHICKPEAS)', 'DRY EDIBLE, BLACK',
#        'DRY EDIBLE, BLACKEYE', 'DRY EDIBLE, CRANBERRY',
#        'DRY EDIBLE, DARK, RED, KIDNEY', 'DRY EDIBLE, GREAT NORTHERN',
#        'DRY EDIBLE, INCL CHICKPEAS', 'DRY EDIBLE, LIGHT, RED, KIDNEY',
#        'DRY EDIBLE, LIMA', 'DRY EDIBLE, LIMA, BABY',
#        'DRY EDIBLE, LIMA, LARGE', 'DRY EDIBLE, NAVY', 'DRY EDIBLE, OTHER',
#        'DRY EDIBLE, OTHER, NOT LISTED', 'DRY EDIBLE, PINK',
#        'DRY EDIBLE, PINTO', 'DRY EDIBLE, RED, KIDNEY',
#        'DRY EDIBLE, SMALL, RED', 'DRY EDIBLE, SMALL, WHITE', 'LARGE',
#        'SMALL', 'PIMA', 'UPLAND', 'PRINCIPAL, INCL POTATOES',
#        '(EXCL ALFALFA)', 'ALFALFA', 'INDUSTRIAL', 'PROSO', 'PEPPERMINT',
#        'SPEARMINT', 'DRY EDIBLE', 'LONG GRAIN', 'MEDIUM GRAIN',
#        'SHORT GRAIN', 'NON-OIL TYPE', 'OIL TYPE',
#        'AIR-CURED LIGHT BURLEY (TYPE 31)',
#        'CIGAR BINDER NORTHERN WISCONSIN (TYPE 55)',
#        'CIGAR BINDER SOUTHERN WISCONSIN (TYPE 54)',
#        'FLUE-CURED (CLASS 1)', 'FLUE-CURED EAST NC BELT (TYPE 12)',
#        'FLUE-CURED NC BORD & SC BELT (TYPE 13)',
#        'FLUE-CURED OLD/MID BELTS (TYPE 11)', 'SPRING, (EXCL DURUM)',
#        'SPRING, DURUM', 'WINTER', 'TAME', 'SWEET', 'TART', 'RAISIN TYPE',
#        'TABLE TYPE', 'WINE TYPE', 'MID & NAVEL', 'VALENCIA', 'CLINGSTONE',
#        'FREESTONE', '(EXCL BARTLETT)', 'BARTLETT', 'BLACK', 'RED',
#        'ENGLISH', 'GREEN, LIMA', 'SNAP', 'COLLARD', 'KALE', 'MUSTARD',
#        'TURNIP', 'HEAD', 'LEAF', 'ROMAINE', 'CANTALOUP', 'HONEYDEW',
#        'WATERMELON', 'DRY', 'DRY, SPRING', 'DRY, SUMMER, NON-STORAGE',
#        'DRY, SUMMER, STORAGE', 'GREEN', 'BELL', 'CHILE', 'FALL', 'SPRING',
#        'SUMMER', '10 MAJOR, VARIES BY SEASON',
#        '34 MAJOR, VARIES BY SEASON'], dtype=object)

# %%
for col in results_col:
    desc_num=results_df[col].unique()
    num=len(desc_num)
    print (f'Total number of unique fields in {col} :{num}')
# Out:
# Total number of unique fields in end_code :1
# Total number of unique fields in group_desc :4
# Total number of unique fields in domain_desc :2
# Total number of unique fields in state_alpha :10
# Total number of unique fields in state_fips_code :10
# Total number of unique fields in county_ansi :1
# Total number of unique fields in domaincat_desc :2
# Total number of unique fields in watershed_code :1
# Total number of unique fields in commodity_desc :84
# Total number of unique fields in class_desc :86
# Total number of unique fields in freq_desc :1
# Total number of unique fields in week_ending :1
# Total number of unique fields in state_ansi :10
# Total number of unique fields in statisticcat_desc :5
# Total number of unique fields in watershed_desc :1
# Total number of unique fields in source_desc :1
# Total number of unique fields in CV (%) :1
# Total number of unique fields in asd_code :1
# Total number of unique fields in load_time :155
# Total number of unique fields in state_name :10
# Total number of unique fields in country_code :1
# Total number of unique fields in zip_5 :1
# Total number of unique fields in util_practice_desc :14
# Total number of unique fields in unit_desc :1
# Total number of unique fields in region_desc :1
# Total number of unique fields in country_name :1
# Total number of unique fields in county_name :1
# Total number of unique fields in location_desc :10
# Total number of unique fields in begin_code :1
# Total number of unique fields in county_code :1
# Total number of unique fields in reference_period_desc :1
# Total number of unique fields in Value :3260
# Total number of unique fields in asd_desc :1
# Total number of unique fields in year :27
# Total number of unique fields in agg_level_desc :1
# Total number of unique fields in prodn_practice_desc :6
# Total number of unique fields in congr_district_code :1
# Total number of unique fields in sector_desc :1
# Total number of unique fields in short_desc :391

# %%
drop_columns=['domain_desc','end_code','state_fips_code',
              'county_ansi','domaincat_desc','watershed_code','freq_desc','week_ending',
              'state_ansi','watershed_desc','watershed_desc', 'source_desc',
       'CV (%)', 'asd_code', 'load_time', 'state_name', 'country_code',
       'zip_5', 'util_practice_desc', 'unit_desc', 'region_desc',
       'country_name', 'county_name', 'location_desc', 'begin_code',
       'county_code', 'reference_period_desc',  'asd_desc', 
       'agg_level_desc', 'prodn_practice_desc', 'congr_district_code',
       'sector_desc']

# %%
results_df.drop(columns=drop_columns,axis=1,inplace=True)

# %%
results_df.head()
# Out:
#     group_desc state_alpha domaincat_desc commodity_desc   class_desc  \
# 0  FIELD CROPS          CA  NOT SPECIFIED         BARLEY  ALL CLASSES
# 1  FIELD CROPS          CA  NOT SPECIFIED         BARLEY  ALL CLASSES
# 2  FIELD CROPS          CA  NOT SPECIFIED         BARLEY  ALL CLASSES
# 3  FIELD CROPS          CA  NOT SPECIFIED         BARLEY  ALL CLASSES
# 4  FIELD CROPS          CA  NOT SPECIFIED         BARLEY  ALL CLASSES
#
#   statisticcat_desc   Value  year                short_desc
# 0    AREA HARVESTED  19,000  2022  BARLEY - ACRES HARVESTED
# 1    AREA HARVESTED  13,000  2021  BARLEY - ACRES HARVESTED
# 2    AREA HARVESTED  33,000  2020  BARLEY - ACRES HARVESTED
# 3    AREA HARVESTED  47,000  2019  BARLEY - ACRES HARVESTED
# 4    AREA HARVESTED  26,000  2018  BARLEY - ACRES HARVESTED

# %%
results_df['short_desc'].unique()
# Out:
# array(['BARLEY - ACRES HARVESTED', 'BARLEY - ACRES PLANTED',
#        'BARLEY, IRRIGATED - ACRES HARVESTED',
#        'BARLEY, IRRIGATED - ACRES PLANTED',
#        'BARLEY, NON-IRRIGATED - ACRES HARVESTED',
#        'BARLEY, NON-IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, BLACK - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, BLACK - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, BLACKEYE - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, BLACKEYE - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, CRANBERRY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, CRANBERRY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, DARK, RED, KIDNEY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, DARK, RED, KIDNEY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, GREAT NORTHERN - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, GREAT NORTHERN - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, GREAT NORTHERN, IRRIGATED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, GREAT NORTHERN, IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, INCL CHICKPEAS - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, INCL CHICKPEAS - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, INCL CHICKPEAS, IRRIGATED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, INCL CHICKPEAS, IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, LIGHT, RED, KIDNEY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, LIGHT, RED, KIDNEY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, LIMA - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, LIMA - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, LIMA, IRRIGATED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, LIMA, IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, LIMA, BABY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, LIMA, BABY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, LIMA, LARGE - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, LIMA, LARGE - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, NAVY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, NAVY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, OTHER - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, OTHER - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, OTHER, IRRIGATED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, OTHER, IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, OTHER, NOT LISTED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, OTHER, NOT LISTED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, PINK - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, PINK - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, PINTO - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, PINTO - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, PINTO, IRRIGATED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, PINTO, IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, RED, KIDNEY - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, RED, KIDNEY - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, RED, KIDNEY, IRRIGATED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, RED, KIDNEY, IRRIGATED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, SMALL, RED - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, SMALL, RED - ACRES PLANTED',
#        'BEANS, DRY EDIBLE, SMALL, WHITE - ACRES HARVESTED',
#        'BEANS, DRY EDIBLE, SMALL, WHITE - ACRES PLANTED',
#        'CANOLA - ACRES HARVESTED', 'CANOLA - ACRES PLANTED',
#        'CHICKPEAS - ACRES HARVESTED', 'CHICKPEAS - ACRES PLANTED',
#        'CHICKPEAS, IRRIGATED - ACRES HARVESTED',
#        'CHICKPEAS, IRRIGATED - ACRES PLANTED',
#        'CHICKPEAS, LARGE - ACRES HARVESTED',
#        'CHICKPEAS, LARGE - ACRES PLANTED',
#        'CHICKPEAS, SMALL - ACRES HARVESTED',
#        'CHICKPEAS, SMALL - ACRES PLANTED', 'CORN - ACRES PLANTED',
#        'CORN, GRAIN - ACRES HARVESTED', 'CORN, SILAGE - ACRES HARVESTED',
#        'CORN, IRRIGATED - ACRES PLANTED',
#        'CORN, GRAIN, IRRIGATED - ACRES HARVESTED',
#        'CORN, SILAGE, IRRIGATED - ACRES HARVESTED',
#        'CORN, NON-IRRIGATED - ACRES PLANTED',
#        'CORN, GRAIN, NON-IRRIGATED - ACRES HARVESTED',
#        'CORN, SILAGE, NON-IRRIGATED - ACRES HARVESTED',
#        'COTTON - ACRES HARVESTED', 'COTTON - ACRES PLANTED',
#        'COTTON, PIMA - ACRES HARVESTED', 'COTTON, PIMA - ACRES PLANTED',
#        'COTTON, PIMA, IRRIGATED - ACRES HARVESTED',
#        'COTTON, PIMA, IRRIGATED - ACRES PLANTED',
#        'COTTON, PIMA, NON-IRRIGATED - ACRES HARVESTED',
#        'COTTON, PIMA, NON-IRRIGATED - ACRES PLANTED',
#        'COTTON, UPLAND - ACRES HARVESTED',
#        'COTTON, UPLAND - ACRES PLANTED',
#        'COTTON, UPLAND, IRRIGATED - ACRES HARVESTED',
#        'COTTON, UPLAND, IRRIGATED - ACRES PLANTED',
#        'COTTON, UPLAND, NON-IRRIGATED - ACRES HARVESTED',
#        'COTTON, UPLAND, NON-IRRIGATED - ACRES PLANTED',
#        'FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ACRES HARVESTED',
#        'FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ACRES PLANTED',
#        'FLAXSEED - ACRES HARVESTED', 'FLAXSEED - ACRES PLANTED',
#        'HAY, (EXCL ALFALFA) - ACRES HARVESTED',
#        'HAY, ALFALFA - ACRES HARVESTED',
#        'HAY, ALFALFA, IRRIGATED - ACRES HARVESTED',
#        'HAY, ALFALFA, NON-IRRIGATED - ACRES HARVESTED',
#        'HAY - ACRES HARVESTED',
#        'HAY & HAYLAGE, (EXCL ALFALFA) - ACRES HARVESTED',
#        'HAY & HAYLAGE, ALFALFA - ACRES HARVESTED',
#        'HAY & HAYLAGE, ALFALFA - ACRES PLANTED',
#        'HAY & HAYLAGE - ACRES HARVESTED',
#        'HAYLAGE, (EXCL ALFALFA) - ACRES HARVESTED',
#        'HAYLAGE, ALFALFA - ACRES HARVESTED', 'HAYLAGE - ACRES HARVESTED',
#        'HEMP, INDUSTRIAL, IN THE OPEN - ACRES HARVESTED',
#        'HEMP, INDUSTRIAL, IN THE OPEN - ACRES PLANTED',
#        'HEMP, INDUSTRIAL, IN THE OPEN, FIBER - ACRES HARVESTED',
#        'HEMP, INDUSTRIAL, IN THE OPEN, FLORAL - ACRES HARVESTED',
#        'MILLET, PROSO - ACRES HARVESTED', 'MILLET, PROSO - ACRES PLANTED',
#        'MINT, PEPPERMINT, OIL - ACRES HARVESTED',
#        'MINT, SPEARMINT, OIL - ACRES HARVESTED', 'OATS - ACRES HARVESTED',
#        'OATS - ACRES PLANTED', 'OATS, IRRIGATED - ACRES HARVESTED',
#        'OATS, IRRIGATED - ACRES PLANTED',
#        'OATS, NON-IRRIGATED - ACRES HARVESTED',
#        'OATS, NON-IRRIGATED - ACRES PLANTED', 'PEANUTS - ACRES HARVESTED',
#        'PEANUTS - ACRES PLANTED', 'PEANUTS, IRRIGATED - ACRES HARVESTED',
#        'PEANUTS, IRRIGATED - ACRES PLANTED',
#        'PEANUTS, NON-IRRIGATED - ACRES HARVESTED',
#        'PEANUTS, NON-IRRIGATED - ACRES PLANTED',
#        'PEAS, DRY EDIBLE - ACRES HARVESTED',
#        'PEAS, DRY EDIBLE - ACRES PLANTED', 'RICE - ACRES HARVESTED',
#        'RICE - ACRES PLANTED', 'RICE, LONG GRAIN - ACRES HARVESTED',
#        'RICE, LONG GRAIN - ACRES PLANTED',
#        'RICE, MEDIUM GRAIN - ACRES HARVESTED',
#        'RICE, MEDIUM GRAIN - ACRES PLANTED',
#        'RICE, SHORT GRAIN - ACRES HARVESTED',
#        'RICE, SHORT GRAIN - ACRES PLANTED', 'RYE - ACRES HARVESTED',
#        'RYE - ACRES PLANTED', 'SAFFLOWER - ACRES HARVESTED',
#        'SAFFLOWER - ACRES PLANTED', 'SORGHUM - ACRES PLANTED',
#        'SORGHUM, GRAIN - ACRES HARVESTED',
#        'SORGHUM, SILAGE - ACRES HARVESTED',
#        'SORGHUM, IRRIGATED - ACRES PLANTED',
#        'SORGHUM, GRAIN, IRRIGATED - ACRES HARVESTED',
#        'SORGHUM, NON-IRRIGATED - ACRES PLANTED',
#        'SORGHUM, GRAIN, NON-IRRIGATED - ACRES HARVESTED',
#        'SOYBEANS - ACRES HARVESTED', 'SOYBEANS - ACRES PLANTED',
#        'SOYBEANS, IRRIGATED - ACRES HARVESTED',
#        'SOYBEANS, IRRIGATED - ACRES PLANTED',
#        'SOYBEANS, NON-IRRIGATED - ACRES HARVESTED',
#        'SOYBEANS, NON-IRRIGATED - ACRES PLANTED',
#        'SUGARBEETS - ACRES HARVESTED', 'SUGARBEETS - ACRES PLANTED',
#        'SUGARCANE, SEED - ACRES HARVESTED',
#        'SUGARCANE, SUGAR - ACRES HARVESTED',
#        'SUGARCANE, SUGAR & SEED - ACRES HARVESTED',
#        'SUNFLOWER - ACRES HARVESTED', 'SUNFLOWER - ACRES PLANTED',
#        'SUNFLOWER, NON-OIL TYPE - ACRES HARVESTED',
#        'SUNFLOWER, NON-OIL TYPE - ACRES PLANTED',
#        'SUNFLOWER, OIL TYPE - ACRES HARVESTED',
#        'SUNFLOWER, OIL TYPE - ACRES PLANTED',
#        'TOBACCO, AIR-CURED LIGHT BURLEY (TYPE 31) - ACRES HARVESTED',
#        'TOBACCO - ACRES HARVESTED',
#        'TOBACCO, CIGAR BINDER NORTHERN WISCONSIN (TYPE 55) - ACRES HARVESTED',
#        'TOBACCO, CIGAR BINDER SOUTHERN WISCONSIN (TYPE 54) - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED (CLASS 1) - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED (CLASS 1), IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED (CLASS 1), NON-IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED EAST NC BELT (TYPE 12) - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED EAST NC BELT (TYPE 12), IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED EAST NC BELT (TYPE 12), NON-IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED NC BORD & SC BELT (TYPE 13) - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED NC BORD & SC BELT (TYPE 13), IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED NC BORD & SC BELT (TYPE 13), NON-IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED OLD/MID BELTS (TYPE 11) - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED OLD/MID BELTS (TYPE 11), IRRIGATED - ACRES HARVESTED',
#        'TOBACCO, FLUE-CURED OLD/MID BELTS (TYPE 11), NON-IRRIGATED - ACRES HARVESTED',
#        'WHEAT - ACRES HARVESTED', 'WHEAT - ACRES PLANTED',
#        'WHEAT, IRRIGATED - ACRES HARVESTED',
#        'WHEAT, IRRIGATED - ACRES PLANTED',
#        'WHEAT, NON-IRRIGATED - ACRES HARVESTED',
#        'WHEAT, NON-IRRIGATED - ACRES PLANTED',
#        'WHEAT, NON-IRRIGATED, CONTINUOUS CROP - ACRES HARVESTED',
#        'WHEAT, NON-IRRIGATED, CONTINUOUS CROP - ACRES PLANTED',
#        'WHEAT, NON-IRRIGATED, FOLLOWING SUMMER FALLOW - ACRES HARVESTED',
#        'WHEAT, NON-IRRIGATED, FOLLOWING SUMMER FALLOW - ACRES PLANTED',
#        'WHEAT, SPRING, (EXCL DURUM) - ACRES HARVESTED',
#        'WHEAT, SPRING, (EXCL DURUM) - ACRES PLANTED',
#        'WHEAT, SPRING, DURUM - ACRES HARVESTED',
#        'WHEAT, SPRING, DURUM - ACRES PLANTED',
#        'WHEAT, SPRING, DURUM, IRRIGATED - ACRES HARVESTED',
#        'WHEAT, SPRING, DURUM, IRRIGATED - ACRES PLANTED',
#        'WHEAT, SPRING, DURUM, NON-IRRIGATED - ACRES PLANTED',
#        'WHEAT, WINTER - ACRES HARVESTED', 'WHEAT, WINTER - ACRES PLANTED',
#        'WHEAT, WINTER, IRRIGATED - ACRES HARVESTED',
#        'WHEAT, WINTER, IRRIGATED - ACRES PLANTED',
#        'WHEAT, WINTER, NON-IRRIGATED - ACRES HARVESTED',
#        'WHEAT, WINTER, NON-IRRIGATED - ACRES PLANTED',
#        'WHEAT, WINTER, NON-IRRIGATED, CONTINUOUS CROP - ACRES HARVESTED',
#        'WHEAT, WINTER, NON-IRRIGATED, CONTINUOUS CROP - ACRES PLANTED',
#        'WHEAT, WINTER, NON-IRRIGATED, FOLLOWING SUMMER FALLOW - ACRES HARVESTED',
#        'WHEAT, WINTER, NON-IRRIGATED, FOLLOWING SUMMER FALLOW - ACRES PLANTED',
#        'ALMONDS - ACRES BEARING', 'APPLES - ACRES BEARING',
#        'APRICOTS - ACRES BEARING', 'AVOCADOS - ACRES BEARING',
#        'BLUEBERRIES, TAME - ACRES HARVESTED',
#        'BOYSENBERRIES - ACRES HARVESTED',
#        'CHERRIES, SWEET - ACRES BEARING',
#        'CHERRIES, TART - ACRES BEARING', 'CITRUS TOTALS - ACRES BEARING',
#        'CRANBERRIES - ACRES HARVESTED', 'DATES - ACRES BEARING',
#        'FIGS - ACRES BEARING', 'GRAPEFRUIT - ACRES BEARING',
#        'GRAPES - ACRES BEARING', 'GRAPES, RAISIN TYPE - ACRES BEARING',
#        'GRAPES, TABLE TYPE - ACRES BEARING',
#        'GRAPES, WINE TYPE - ACRES BEARING', 'KIWIFRUIT - ACRES BEARING',
#        'LEMONS - ACRES BEARING', 'NECTARINES - ACRES BEARING',
#        'OLIVES - ACRES BEARING', 'ORANGES - ACRES BEARING',
#        'ORANGES, MID & NAVEL - ACRES BEARING',
#        'ORANGES, VALENCIA - ACRES BEARING', 'PEACHES - ACRES BEARING',
#        'PEACHES, CLINGSTONE - ACRES BEARING',
#        'PEACHES, FREESTONE - ACRES BEARING',
#        'PEACHES, FREESTONE - ACRES TOTAL',
#        'PEARS, (EXCL BARTLETT) - ACRES BEARING', 'PEARS - ACRES BEARING',
#        'PEARS, BARTLETT - ACRES BEARING', 'PECANS - ACRES BEARING',
#        'PISTACHIOS - ACRES BEARING', 'PLUMS - ACRES BEARING',
#        'PRUNES - ACRES BEARING', 'RASPBERRIES - ACRES HARVESTED',
#        'RASPBERRIES, BLACK - ACRES HARVESTED',
#        'RASPBERRIES, RED - ACRES HARVESTED',
#        'STRAWBERRIES - ACRES HARVESTED', 'STRAWBERRIES - ACRES PLANTED',
#        'TANGERINES - ACRES BEARING', 'WALNUTS, ENGLISH - ACRES BEARING',
#        'FLORICULTURE TOTALS, IN THE OPEN - ACRES IN PRODUCTION',
#        'ARTICHOKES - ACRES HARVESTED', 'ARTICHOKES - ACRES PLANTED',
#        'ASPARAGUS - ACRES HARVESTED', 'ASPARAGUS - ACRES PLANTED',
#        'BEANS, GREEN, LIMA - ACRES HARVESTED',
#        'BEANS, GREEN, LIMA - ACRES PLANTED',
#        'BEANS, GREEN, LIMA, FRESH MARKET - ACRES HARVESTED',
#        'BEANS, GREEN, LIMA, FRESH MARKET - ACRES PLANTED',
#        'BEANS, SNAP - ACRES HARVESTED', 'BEANS, SNAP - ACRES PLANTED',
#        'BEANS, SNAP, FRESH MARKET - ACRES HARVESTED',
#        'BEANS, SNAP, FRESH MARKET - ACRES PLANTED',
#        'BEANS, SNAP, PROCESSING - ACRES HARVESTED',
#        'BEANS, SNAP, PROCESSING - ACRES PLANTED',
#        'BEETS, PROCESSING - ACRES HARVESTED',
#        'BEETS, PROCESSING - ACRES PLANTED', 'BROCCOLI - ACRES HARVESTED',
#        'BROCCOLI - ACRES PLANTED', 'BRUSSELS SPROUTS - ACRES HARVESTED',
#        'BRUSSELS SPROUTS - ACRES PLANTED', 'CABBAGE - ACRES HARVESTED',
#        'CABBAGE - ACRES PLANTED',
#        'CABBAGE, FRESH MARKET - ACRES HARVESTED',
#        'CABBAGE, FRESH MARKET - ACRES PLANTED',
#        'CABBAGE, PROCESSING - ACRES HARVESTED',
#        'CABBAGE, PROCESSING - ACRES PLANTED', 'CARROTS - ACRES HARVESTED',
#        'CARROTS - ACRES PLANTED',
#        'CARROTS, FRESH MARKET - ACRES HARVESTED',
#        'CARROTS, FRESH MARKET - ACRES PLANTED',
#        'CARROTS, PROCESSING - ACRES HARVESTED',
#        'CARROTS, PROCESSING - ACRES PLANTED',
#        'CAULIFLOWER - ACRES HARVESTED', 'CAULIFLOWER - ACRES PLANTED',
#        'CELERY - ACRES HARVESTED', 'CELERY - ACRES PLANTED',
#        'CUCUMBERS - ACRES HARVESTED', 'CUCUMBERS - ACRES PLANTED',
#        'CUCUMBERS, FRESH MARKET - ACRES HARVESTED',
#        'CUCUMBERS, FRESH MARKET - ACRES PLANTED',
#        'CUCUMBERS, PROCESSING, PICKLES - ACRES HARVESTED',
#        'CUCUMBERS, PROCESSING, PICKLES - ACRES PLANTED',
#        'EGGPLANT, FRESH MARKET - ACRES HARVESTED',
#        'EGGPLANT, FRESH MARKET - ACRES PLANTED',
#        'ESCAROLE & ENDIVE, FRESH MARKET - ACRES HARVESTED',
#        'ESCAROLE & ENDIVE, FRESH MARKET - ACRES PLANTED',
#        'GARLIC - ACRES HARVESTED', 'GARLIC - ACRES PLANTED',
#        'GREENS, COLLARD - ACRES HARVESTED',
#        'GREENS, COLLARD - ACRES PLANTED',
#        'GREENS, KALE - ACRES HARVESTED', 'GREENS, KALE - ACRES PLANTED',
#        'GREENS, MUSTARD - ACRES HARVESTED',
#        'GREENS, MUSTARD - ACRES PLANTED',
#        'GREENS, TURNIP - ACRES HARVESTED',
#        'GREENS, TURNIP - ACRES PLANTED',
#        'LETTUCE, HEAD - ACRES HARVESTED', 'LETTUCE, HEAD - ACRES PLANTED',
#        'LETTUCE, HEAD, FRESH MARKET - ACRES HARVESTED',
#        'LETTUCE, HEAD, FRESH MARKET - ACRES PLANTED',
#        'LETTUCE, LEAF - ACRES HARVESTED', 'LETTUCE, LEAF - ACRES PLANTED',
#        'LETTUCE, LEAF, FRESH MARKET - ACRES HARVESTED',
#        'LETTUCE, LEAF, FRESH MARKET - ACRES PLANTED',
#        'LETTUCE, ROMAINE - ACRES HARVESTED',
#        'LETTUCE, ROMAINE - ACRES PLANTED',
#        'LETTUCE, ROMAINE, FRESH MARKET - ACRES HARVESTED',
#        'LETTUCE, ROMAINE, FRESH MARKET - ACRES PLANTED',
#        'MELONS, CANTALOUP - ACRES HARVESTED',
#        'MELONS, CANTALOUP - ACRES PLANTED',
#        'MELONS, CANTALOUP, FRESH MARKET - ACRES HARVESTED',
#        'MELONS, CANTALOUP, FRESH MARKET - ACRES PLANTED',
#        'MELONS, HONEYDEW - ACRES HARVESTED',
#        'MELONS, HONEYDEW - ACRES PLANTED',
#        'MELONS, HONEYDEW, FRESH MARKET - ACRES HARVESTED',
#        'MELONS, HONEYDEW, FRESH MARKET - ACRES PLANTED',
#        'MELONS, WATERMELON - ACRES HARVESTED',
#        'MELONS, WATERMELON - ACRES PLANTED',
#        'MELONS, WATERMELON, FRESH MARKET - ACRES HARVESTED',
#        'MELONS, WATERMELON, FRESH MARKET - ACRES PLANTED',
#        'OKRA - ACRES HARVESTED', 'OKRA - ACRES PLANTED',
#        'ONIONS, DRY - ACRES HARVESTED', 'ONIONS, DRY - ACRES PLANTED',
#        'ONIONS, DRY, SPRING - ACRES HARVESTED',
#        'ONIONS, DRY, SPRING - ACRES PLANTED',
#        'ONIONS, DRY, SUMMER, NON-STORAGE - ACRES HARVESTED',
#        'ONIONS, DRY, SUMMER, NON-STORAGE - ACRES PLANTED',
#        'ONIONS, DRY, SUMMER, STORAGE - ACRES HARVESTED',
#        'ONIONS, DRY, SUMMER, STORAGE - ACRES PLANTED',
#        'PEAS, GREEN - ACRES HARVESTED', 'PEAS, GREEN - ACRES PLANTED',
#        'PEAS, GREEN, PROCESSING - ACRES HARVESTED',
#        'PEAS, GREEN, PROCESSING - ACRES PLANTED',
#        'PEPPERS, BELL - ACRES HARVESTED', 'PEPPERS, BELL - ACRES PLANTED',
#        'PEPPERS, CHILE - ACRES HARVESTED',
#        'PEPPERS, CHILE - ACRES PLANTED', 'POTATOES - ACRES HARVESTED',
#        'POTATOES - ACRES PLANTED',
#        'POTATOES, SEED, CERTIFIED - ACRES PLANTED',
#        'POTATOES, SEED, ENTERED FOR CERTIFICATION - ACRES PLANTED',
#        'POTATOES, FALL - ACRES HARVESTED',
#        'POTATOES, FALL - ACRES PLANTED',
#        'POTATOES, SPRING - ACRES HARVESTED',
#        'POTATOES, SPRING - ACRES PLANTED',
#        'POTATOES, SUMMER - ACRES HARVESTED',
#        'POTATOES, SUMMER - ACRES PLANTED',
#        'POTATOES, WINTER - ACRES HARVESTED',
#        'POTATOES, WINTER - ACRES PLANTED', 'PUMPKINS - ACRES HARVESTED',
#        'PUMPKINS - ACRES PLANTED', 'RADISHES - ACRES HARVESTED',
#        'RADISHES - ACRES PLANTED', 'SPINACH - ACRES HARVESTED',
#        'SPINACH - ACRES PLANTED',
#        'SPINACH, FRESH MARKET - ACRES HARVESTED',
#        'SPINACH, FRESH MARKET - ACRES PLANTED',
#        'SPINACH, PROCESSING - ACRES HARVESTED',
#        'SPINACH, PROCESSING - ACRES PLANTED', 'SQUASH - ACRES HARVESTED',
#        'SQUASH - ACRES PLANTED', 'SWEET CORN - ACRES HARVESTED',
#        'SWEET CORN - ACRES PLANTED',
#        'SWEET CORN, FRESH MARKET - ACRES HARVESTED',
#        'SWEET CORN, FRESH MARKET - ACRES PLANTED',
#        'SWEET CORN, PROCESSING - ACRES HARVESTED',
#        'SWEET CORN, PROCESSING - ACRES PLANTED',
#        'SWEET POTATOES - ACRES HARVESTED',
#        'SWEET POTATOES - ACRES PLANTED',
#        'TOMATOES, IN THE OPEN - ACRES HARVESTED',
#        'TOMATOES, IN THE OPEN - ACRES PLANTED',
#        'TOMATOES, IN THE OPEN, FRESH MARKET - ACRES HARVESTED',
#        'TOMATOES, IN THE OPEN, FRESH MARKET - ACRES PLANTED',
#        'TOMATOES, IN THE OPEN, PROCESSING - ACRES HARVESTED',
#        'TOMATOES, IN THE OPEN, PROCESSING - ACRES PLANTED',
#        'VEGETABLE TOTALS, 10 MAJOR, VARIES BY SEASON, PROCESSING - ACRES HARVESTED',
#        'VEGETABLE TOTALS, 10 MAJOR, VARIES BY SEASON, PROCESSING - ACRES PLANTED',
#        'VEGETABLE TOTALS, 34 MAJOR, VARIES BY SEASON, FRESH MARKET - ACRES HARVESTED',
#        'VEGETABLE TOTALS, 34 MAJOR, VARIES BY SEASON, FRESH MARKET - ACRES PLANTED',
#        'VEGETABLE TOTALS - ACRES HARVESTED',
#        'VEGETABLE TOTALS - ACRES PLANTED'], dtype=object)

# %%
results_df['state_alpha'].unique()
# Out:
# array(['CA', 'KS', 'MN', 'NE', 'NC', 'TX', 'WI', 'IL', 'IN', 'IA'],
#       dtype=object)

# %%
results_df['Value']=results_df['Value'].str.replace(',','')
results_df=results_df[results_df['Value'].str.isdigit()== True]
results_df['Value']=results_df['Value'].astype(int)
results_df['Value'].describe()
# Out:
# count    1.825500e+04
# mean     1.190070e+06
# std      3.366792e+06
# min      0.000000e+00
# 25%      9.000000e+03
# 50%      5.000000e+04
# 75%      4.880000e+05
# max      2.502000e+07
# Name: Value, dtype: float64

# %%
results_df.dtypes
# Out:
# group_desc           object
# state_alpha          object
# commodity_desc       object
# class_desc           object
# statisticcat_desc    object
# Value                 int32
# year                  int64
# short_desc           object
# dtype: object

# %%
results_df.groupby('state_alpha')['Value'].describe()
# Out:
#               count          mean           std    min      25%       50%  \
# state_alpha
# CA           4431.0  1.662507e+05  4.624432e+05    0.0   9000.0   31000.0
# IA            563.0  4.611349e+06  7.667978e+06   95.0  45000.0  330000.0
# IL            996.0  2.464594e+06  5.799435e+06    0.0   9225.0   44350.0
# IN            894.0  1.445231e+06  3.194133e+06   67.0   4900.0   15000.0
# KS           1609.0  2.708174e+06  4.600475e+06    0.0  37000.0  545000.0
# MN           1786.0  1.260180e+06  3.605768e+06    0.0  19450.0   66000.0
# NC           1574.0  3.521499e+05  8.705846e+05  160.0   5500.0   18800.0
# NE           1903.0  1.531209e+06  3.477503e+06    0.0  28000.0  120000.0
# TX           3019.0  1.160502e+06  2.979313e+06    0.0   6100.0   38000.0
# WI           1480.0  7.197615e+05  1.611385e+06    0.0   5600.0   66000.0
#
#                    75%         max
# state_alpha
# CA            114000.0   5193000.0
# IA           9565000.0  25020000.0
# IL            612500.0  23651000.0
# IN            430000.0  12909000.0
# KS           3388000.0  24421000.0
# MN            434000.0  20520000.0
# NC            365000.0   5073000.0
# NE           1600000.0  19810000.0
# TX            838000.0  24843000.0
# WI            440000.0   8318000.0

# %%
results_df.to_json('products.json')

# %%
results_df['year'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001,
#        2000, 1999, 1998, 1997, 2023], dtype=int64)
